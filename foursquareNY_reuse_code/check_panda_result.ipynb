# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
import re

# %%
# df = pd.read_csv("header_binary_matrix.csv")
# list_df = df.columns.tolist()

# %%
dic = {}

for i in range(len(list_df)):
  dic[i] = list_df[i]

# %%
print(dic)

# %% [markdown]
# ### FS-NY-top10

# %%
file = "./output_clustering/fs_ny_top_10_fimi_result.txt"
# file = "./output_clustering/fs_ny_top_10_fimi_result_2.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
tmp1 = columnClusters[5]
tmp2 = rowClusters[5]
columnClusters[5] = columnClusters[-1]
rowClusters[5] = rowClusters[-1]
columnClusters[-1] = tmp1
rowClusters[-1] = tmp2
del df_fimi
check_result(columnClusters,rowClusters,top10_dict)
# Out:
# Cluster-1 (41)
# Atributos: Home_(private), Office, Park,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)| [Deli_/_Bodega, Pizza_Place, Home_(private), Park, Chinese_Restaurant, Bakery, Smoke_Shop, Radio_Station, Cafeteria, Metro_Station, ] QTD pacientes: 18
#     Cluster 3: 51.22% (21)| [Bank, Hotel, Office, ] QTD pacientes: 58
#     Cluster 4: 0.00% (0)| [Deli_/_Bodega, Pizza_Place, Gas_Station, Chinese_Restaurant, Supermarket, Salon_/_Barbershop, ] QTD pacientes: 25
#     Cluster 5: 0.00% (0)| [American_Restaurant, Metro_Station, Fast_Food_Restaurant, IT_Services, Beach, ] QTD pacientes: 11
#     Cluster 6: 0.00% (0)| [Home_(private), Bus_Line, Park, Metro_Station, Smoke_Shop, Radio_Station, ] QTD pacientes: 20
#     Cluster 7: 58.54% (24)| [Home_(private), American_Restaurant, Office, ] QTD pacientes: 35
#     Cluster 8: 4.88% (2)| [Deli_/_Bodega, Metro_Station, Building, Coffee_Shop, ] QTD pacientes: 25
# ...

# %%
heatmap_vis(columnClusters,rowClusters)

# %%
chord_vis(columnClusters,rowClusters)
# ta = [['a','b','c','d'],['a','b','c','d']]
# to = [[0,1,2,3],[4,5,6,7]]
# chord_vis(ta,to)
# Out:
# New nodes:  ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10']
# Size links: (10, 10)

# %% [markdown]
# # Analysis
# Para mais detalhes dos experimentos consulte os relatório técnico.

# %% [markdown]
# ### Experimento 1 - Assintomáticos e Sintomáticos
# Nessa primeira parte analisamos os dados misturados com assintomáticos, sintomáticos e mais alguns atributos. Nos próximos experimentos nós devemos explorar novos atributos e subconjutos dos dados.

# %%
my_dict = {0: 'SexF', 1: 'SexM', 2: 'Bebe', 3: 'Crianca', 4: 'Jovem', 5: 'Adulto', 6: 'Idoso', 7: 'Muito_idoso', 
           8: 'Conf_Fev', 9: 'Conf_Mar', 10: 'Conf_Abr', 11: 'Conf_Mai', 12: 'Conf_Jun', 13: 'Conf_Jul', 14: 'Conf_Ago', 
           15: 'Conf_Set', 16: 'Sint_Fev', 17: 'Sint_Mar', 18: 'Sint_Abr', 19: 'Sint_Mai', 20: 'Sint_Jun', 21: 'Sint_Jul', 
           22: 'Sint_Ago', 23: 'Sint_Set', 24: 'Evo_Rec', 25: 'Evo_Obito', 26: 'Evo_Aco', 27: 'Hosp_S', 28: 'Hosp_N', 
           29: 'Febre_S', 30: 'Febre_N', 31: 'Tosse_S', 32: 'Tosse_N', 33: 'Garganta_S', 34: 'Garganta_N', 35: 'Dispneia_S', 
           36: 'Dispneia_N', 37: 'Asma_S', 38: 'Asma_N', 39: 'DRespiratoria_S', 40: 'DRespiratoria_N', 41: 'DNeurologia_S', 
           42: 'DNeurologia_N', 43: 'Diabetes_S', 44: 'Diabetes_N', 45: 'Imunodef_S', 46: 'Imunodef_N', 47: 'DRenal_S', 
           48: 'DRenal_N', 49: 'DHepatica_S', 50: 'DHepatica_N', 51: 'DCardiaca_S', 52: 'DCardiaca_N', 53: 'Obesidade_S', 
           54: 'Obesidade_N'}

# %%
# file = "./output_clustering/covid1_res_k2.txt"
# file = "./output_clustering/covid1_res_k3.txt"
# file = "./output_clustering/covid1_res_k4.txt"
# file = "./output_clustering/covid1_res_k5.txt"
file = "./output_clustering/covid1_res_k6.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi

# %%
check_result(columnClusters,rowClusters,my_dict)
# Out:
# Cluster-1 (147385)
# Atributos: DHepatica_N, Asma_N, DNeurologia_N, DRenal_N, Obesidade_N, Imunodef_N, DRespiratoria_N, Diabetes_N, DCardiaca_N, Evo_Rec, Hosp_N,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 31.07% (45794)
#     Cluster 3: 13.09% (19297)
#     Cluster 4: 32.92% (48513)
#     Cluster 5: 14.81% (21825)
#     Cluster 6: 15.33% (22591)
#
#
# Cluster-2 (46203)
# Atributos: Dispneia_N, Adulto, Garganta_N, Febre_N, Tosse_N,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 1: 99.11% (45794)
#     Cluster 3: 0.00% (0)
#     Cluster 4: 50.79% (23465)
#     Cluster 5: 14.99% (6926)
#     Cluster 6: 0.00% (0)
#
#
# Cluster-3 (19817)
# Atributos: Dispneia_N, SexF, Adulto, Tosse_S,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 1: 97.38% (19297)
#     Cluster 2: 0.00% (0)
#     Cluster 4: 0.00% (0)
#     Cluster 5: 27.95% (5539)
#     Cluster 6: 54.75% (10850)
#
#
# Cluster-4 (50340)
# Atributos: SexM, Garganta_N, Dispneia_N,
# ...

# %% [markdown]
# ## Co-clustering methods - scikit-learn
# 1) https://scikit-learn.org/stable/modules/classes.html#module-sklearn.cluster
#
# 2) https://scikit-learn.org/stable/modules/biclustering.html#biclustering

# %%
file1 = "Toy1_b4_binary_forcocluster.dat"
path1 = './input_datasets/'+file1
file2 = "Toy1_b4_binary_fortraditional.dat"
path2 = './input_datasets/'+file2

df = pd.read_csv(path1,header=None)
df2 = pd.read_csv(path2,header=None)
data = df.values.copy()
data2 = df2.values.copy()
print(data.shape)
print(data2.shape)

fig , (ax1,ax2) = plt.subplots(1,2, figsize=(14,8))
fig.figsize = (19,19)
#plt.subplot(1,2,1)
#plt.matshow(data, cmap=plt.cm.Blues)
ax1.matshow(data, cmap=plt.cm.Blues,aspect="auto")
#plt.title("Binary dataset for co-clusters")
ax1.set_title("Binary dataset for co-clusters")

#plt.subplot(1,2,2)
#plt.matshow(data2, cmap=plt.cm.Blues)
ax2.matshow(data2, cmap=plt.cm.Blues,aspect="auto")
#plt.title("Binary dataset for traditional methods")
ax2.set_title("Binary dataset for traditional methods")

# %%
from sklearn.cluster.bicluster import SpectralCoclustering
# Out:
# /Users/ricardogiuliani/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.cluster.bicluster module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
data = pd.read_csv('input_datasets/input_new.csv', header=None, sep=' ')
data.shape
# Out:
# (160940, 53)

# %%
clusters = 6
DhillonCocluster = SpectralCoclustering(n_clusters = clusters, random_state = 0)
DhillonCocluster.fit(data)

    
reconstructed_matrix = np.zeros(data.shape,dtype=int)
for nc in range(clusters):
    if len(DhillonCocluster.get_indices(nc)[0]) != 0 and len(DhillonCocluster.get_indices(nc)[1]) != 0:
        for i in DhillonCocluster.get_indices(nc)[0]:#Indices of rows in the dataset that belong to the bicluster.
            for j in DhillonCocluster.get_indices(nc)[1]:#Indices of columns in the dataset that belong to the bicluster.
                reconstructed_matrix[i][j] = 1

# %%
fig , (ax1,ax2) = plt.subplots(1,2, figsize=(14,8))
fig.figsize = (19,19)
#plt.subplot(1,2,1)
#plt.matshow(data, cmap=plt.cm.Blues)
ax1.matshow(data, cmap=plt.cm.Blues,aspect="auto")
#plt.title("Binary dataset for co-clusters")
ax1.set_title("Binary dataset for co-clusters")

#plt.subplot(1,2,2)
#plt.matshow(data2, cmap=plt.cm.Blues)
ax2.matshow(reconstructed_matrix, cmap=plt.cm.Blues,aspect="auto")
#plt.title("Binary dataset for traditional methods")
ax2.set_title("Dhillon output")
# Out:
# Text(0.5, 1.05, 'Dhillon output')

# %% [markdown]
# ### Experimento com dataset completo

# %% [markdown]
# Análise dos 10 grupos mais representativos com o método PaNDa sem ruído.

# %%
# file = "./output_clustering/20201030_binary_res_k10_noNoise.txt"
file = "./output_clustering/20201030_binary_res_k10_noNoise_f.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,covid_dict)
# Out:
# Cluster-1 (62141)
# Atributos: Adulto, Outros_Sint, SexM,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)[SexF, Adulto, Outros_Sint, ]
#     Cluster 3: 22.98% (14281)[Tosse, Febre, ]
#     Cluster 4: 7.46% (4635)[Agosto, Garganta, ]
#     Cluster 5: 0.00% (0)[SexF, Adulto, ]
#     Cluster 6: 26.96% (16753)[SexM, Julho, ]
#     Cluster 7: 7.09% (4405)[Setembro, Tosse, ]
#     Cluster 8: 22.03% (13692)[Agosto, SexM, ]
#     Cluster 9: 6.62% (4111)[Garganta, Dispneia, ]
#     Cluster 10: 14.70% (9135)[PORTO ALEGRE, Tosse, ]
#
# Cluster-2 (54935)
# Atributos: SexF, Adulto, Outros_Sint,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 1: 0.00% (0)[Adulto, Outros_Sint, SexM, ]
#     Cluster 3: 17.28% (9491)[Tosse, Febre, ]
#     Cluster 4: 8.41% (4619)[Agosto, Garganta, ]
#     Cluster 5: 0.00% (0)[SexF, Adulto, ]
#     Cluster 6: 0.00% (0)[SexM, Julho, ]
#     Cluster 7: 5.90% (3243)[Setembro, Tosse, ]
#     Cluster 8: 0.00% (0)[Agosto, SexM, ]
# ...

# %% [markdown]
# ### Experimento 2 - Sintomáticos

# %% [markdown]
# Análise dos 10 grupos mais representativos com o método PaNDa.

# %%
# file = "./output_clustering/20201030_sin_res_k10_noNoise.txt"
# file = "./output_clustering/20201030_sin_res_k10_noNoise_f.txt"
file = "./output_clustering/20201030_sin_res_k10_noNoise_f2.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,covid_dict)

# %%
# Out:
# Cluster-1 (62141)
# Atributos: Adulto, Outros_Sint, SexM,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)[SexF, Tosse, Adulto, ]
#     Cluster 3: 34.06% (21165)[Outros_Sint, Febre, ]
#     Cluster 4: 0.00% (0)[Outros_Sint, SexF, Adulto, ]
#     Cluster 5: 17.78% (11046)[Tosse, Garganta, ]
#     Cluster 6: 29.49% (18327)[Agosto, SexM, ]
#     Cluster 7: 3.63% (2255)[Julho, Dispneia, ]
#     Cluster 8: 8.86% (5503)[Julho, Tosse, ]
#     Cluster 9: 7.14% (4436)[Setembro, PORTO ALEGRE, ]
#     Cluster 10: 0.00% (0)[SexM, Febre, Adulto, ]
#
# Cluster-2 (37297)
# Atributos: SexF, Tosse, Adulto,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 1: 0.00% (0)[Adulto, Outros_Sint, SexM, ]
#     Cluster 3: 25.45% (9491)[Outros_Sint, Febre, ]
#     Cluster 4: 30.36% (11323)[Outros_Sint, SexF, Adulto, ]
#     Cluster 5: 46.92% (17500)[Tosse, Garganta, ]
#     Cluster 6: 0.00% (0)[Agosto, SexM, ]
#     Cluster 7: 6.26% (2333)[Julho, Dispneia, ]
# ...

# %% [markdown]
# ### Experimento 3 - Assintomáticos

# %% [markdown]
# ## Experimento 4 - Pacientes que vieram a óbito

# %% [markdown]
# Análise dos 10 grupos mais representativos com o método PaNDa.
#
# Atributos sobre Hospitalização (Hospitalizado, Hosp_SRAG) mantidos para análise.

# %%
file = "./output_clustering/20201030_death_res_k10_noNoise_f3.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,covid_dict)
# Out:
# Cluster-1 (4485)
# Atributos: Hosp_SRAG, Hospitalizado, Dispneia,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 25.22% (1131)| [Tosse, SexM, Febre, Hosp_SRAG, ] QTD pacientes: 1382
#     Cluster 3: 25.95% (1164)| [Idoso_1, Outras_Comorbidades, Hosp_SRAG, ] QTD pacientes: 1508
#     Cluster 4: 14.52% (651)| [DCardiaca, SexF, Tosse, Hosp_SRAG, ] QTD pacientes: 791
#     Cluster 5: 22.23% (997)| [Diabetes, DCardiaca, Hosp_SRAG, ] QTD pacientes: 1254
#     Cluster 6: 7.92% (355)| [SexM, Febre, Hosp_SRAG, ] QTD pacientes: 464
#     Cluster 7: 6.78% (304)| [SexF, Julho, Febre, Hosp_SRAG, ] QTD pacientes: 397
#     Cluster 8: 4.75% (213)| [Outros_Sint, Idoso_2, Outras_Comorbidades, Hosp_SRAG, ] QTD pacientes: 319
#     Cluster 9: 11.88% (533)| [Agosto, SexF, Hosp_SRAG, ] QTD pacientes: 683
#     Cluster 10: 14.25% (639)| [Idoso_1, Outros_Sint, Hosp_SRAG, ] QTD pacientes: 868
#
# Cluster-2 (1382)
# Atributos: Tosse, SexM, Febre, Hosp_SRAG,
# ...

# %% [markdown]
# Abaixo é a análise com a remoção do atributo Hospitalizados.

# %%
# file = "./output_clustering/20201030_death_res_k10_noNoise.txt"
file = "./output_clustering/20201030_death_res_k10_noNoise_f.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,covid_dict)
# Out:
# Cluster-1 (3005)
# Atributos: Hosp_SRAG, Dispneia, Tosse,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 20.77% (624)| [SexM, Febre, Idoso_1, Hosp_SRAG, ] QTD pacientes: 988
#     Cluster 3: 21.40% (643)| [Outras_Comorbidades, DCardiaca, Hosp_SRAG, ] QTD pacientes: 1260
#     Cluster 4: 25.62% (770)| [SexF, Febre, Hosp_SRAG, ] QTD pacientes: 1310
#     Cluster 5: 20.00% (601)| [SexM, Diabetes, Hosp_SRAG, ] QTD pacientes: 1128
#     Cluster 6: 16.07% (483)| [Idoso_1, Julho, Hosp_SRAG, ] QTD pacientes: 893
#     Cluster 7: 6.16% (185)| [Outros_Sint, Idoso_2, Hosp_SRAG, ] QTD pacientes: 489
#     Cluster 8: 26.59% (799)| [Dispneia, Outras_Comorbidades, Hosp_SRAG, ] QTD pacientes: 1660
#     Cluster 9: 12.51% (376)| [DCardiaca, Agosto, Hosp_SRAG, ] QTD pacientes: 742
#     Cluster 10: 9.88% (297)| [SexM, Idoso_1, Hosp_SRAG, ] QTD pacientes: 713
#
# Cluster-2 (988)
# Atributos: SexM, Febre, Idoso_1, Hosp_SRAG,
# Compartilhamento de OBJETOS em outros clusters.
# ...

# %% [markdown]
# Abaixo é a análise com a remoção do atributos de hospitalização.

# %%
file = "./output_clustering/20201030_death_res_k10_noNoise_f2.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,covid_dict)
# Out:
# Cluster-1 (1174)
# Atributos: Dispneia, Tosse, SexM, Febre,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 25.47% (299)| [Dispneia, Idoso_1, Outras_Comorbidades, ] QTD pacientes: 1204
#     Cluster 3: 0.00% (0)| [DCardiaca, Dispneia, SexF, ] QTD pacientes: 1058
#     Cluster 4: 34.92% (410)| [Tosse, Diabetes, ] QTD pacientes: 1307
#     Cluster 5: 0.00% (0)| [SexM, Febre, ] QTD pacientes: 672
#     Cluster 6: 45.91% (539)| [DCardiaca, Dispneia, SexM, ] QTD pacientes: 1272
#     Cluster 7: 17.72% (208)| [Idoso_1, Julho, ] QTD pacientes: 893
#     Cluster 8: 3.41% (40)| [Outros_Sint, Idoso_2, Outras_Comorbidades, ] QTD pacientes: 319
#     Cluster 9: 0.00% (0)| [Agosto, SexF, Dispneia, ] QTD pacientes: 553
#     Cluster 10: 24.70% (290)| [Tosse, Outros_Sint, ] QTD pacientes: 954
#
# Cluster-2 (1204)
# Atributos: Dispneia, Idoso_1, Outras_Comorbidades,
# Compartilhamento de OBJETOS em outros clusters.
# ...

# %% [markdown]
# Abaixo nós analisamos os $\textbf{10 grupos}$ e depois $\textbf{15 grupos}$ mais representativos no dataset que possui as $regiões$ no lugar dos municipios, sem informação dos testes realizados, raça e mês de óbito.

# %%
file = "./output_clustering/20201030_death_res_k10_noNoise_covid-region_y.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,region_covid)
# Out:
# Cluster-1 (1174)
# Atributos: Dispneia, Tosse, SexM, Febre,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)| [Dispneia, Outras_Comorbidades, SexF, ] QTD pacientes: 1066
#     Cluster 3: 45.91% (539)| [DCardiaca, Dispneia, SexM, ] QTD pacientes: 1272
#     Cluster 4: 34.92% (410)| [Tosse, Diabetes, ] QTD pacientes: 1307
#     Cluster 5: 23.25% (273)| [Febre, PORTO ALEGRE - R10, ] QTD pacientes: 943
#     Cluster 6: 14.91% (175)| [Outras_Comorbidades, Julho, ] QTD pacientes: 855
#     Cluster 7: 0.00% (0)| [Outros_Sint, Dispneia, SexF, ] QTD pacientes: 569
#     Cluster 8: 11.50% (135)| [Idoso_3, DCardiaca, ] QTD pacientes: 913
#     Cluster 9: 6.47% (76)| [Idoso_2, Agosto, ] QTD pacientes: 416
#     Cluster 10: 0.00% (0)| [Dispneia, Tosse, SexF, ] QTD pacientes: 981
#
# Cluster-2 (1066)
# Atributos: Dispneia, Outras_Comorbidades, SexF,
# Compartilhamento de OBJETOS em outros clusters.
# ...

# %%
file = "./output_clustering/20201030_death_res_k15_noNoise_covid-region_y.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,region_covid)
# Out:
# Cluster-1 (1174)
# Atributos: Dispneia, Tosse, SexM, Febre,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)| [Dispneia, Outras_Comorbidades, SexF, ] QTD pacientes: 1066
#     Cluster 3: 45.91% (539)| [DCardiaca, Dispneia, SexM, ] QTD pacientes: 1272
#     Cluster 4: 34.92% (410)| [Tosse, Diabetes, ] QTD pacientes: 1307
#     Cluster 5: 23.25% (273)| [Febre, PORTO ALEGRE - R10, ] QTD pacientes: 943
#     Cluster 6: 14.91% (175)| [Outras_Comorbidades, Julho, ] QTD pacientes: 855
#     Cluster 7: 0.00% (0)| [Outros_Sint, Dispneia, SexF, ] QTD pacientes: 569
#     Cluster 8: 11.50% (135)| [Idoso_3, DCardiaca, ] QTD pacientes: 913
#     Cluster 9: 6.47% (76)| [Idoso_2, Agosto, ] QTD pacientes: 416
#     Cluster 10: 0.00% (0)| [Dispneia, Tosse, SexF, ] QTD pacientes: 981
#     Cluster 11: 27.51% (323)| [Idoso_1, Febre, ] QTD pacientes: 755
#     Cluster 12: 30.41% (357)| [SexM, Outras_Comorbidades, Dispneia, ] QTD pacientes: 977
# ...

# %% [markdown]
# Nessas 2 próximas análises nós continuamos com $\textbf{10}$ e $\textbf{15}$ $\textbf{grupos}$ com foco na $região$, mas agora o dataset tem a informação sobre o $\textbf{mês de óbito}$. A intenção é comparar os resultados com o dataset que contém as informações do municipio.

# %%
file = "./output_clustering/20201030_death_res_k10_noNoise_region_obito_y.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,region_obito_mes)
# Out:
# Cluster-1 (1174)
# Atributos: Dispneia, Tosse, SexM, Febre,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)| [Dispneia, Outras_Comorbidades, SexF, ] QTD pacientes: 1066
#     Cluster 3: 45.91% (539)| [DCardiaca, Dispneia, SexM, ] QTD pacientes: 1272
#     Cluster 4: 34.92% (410)| [Tosse, Diabetes, ] QTD pacientes: 1307
#     Cluster 5: 23.25% (273)| [Febre, PORTO ALEGRE - R10, ] QTD pacientes: 943
#     Cluster 6: 8.26% (97)| [Outras_Comorbidades, Julho, Obito_Julho, ] QTD pacientes: 467
#     Cluster 7: 0.00% (0)| [Outros_Sint, Dispneia, SexF, ] QTD pacientes: 569
#     Cluster 8: 11.50% (135)| [Idoso_3, DCardiaca, ] QTD pacientes: 913
#     Cluster 9: 3.92% (46)| [Idoso_2, Obito_Agosto, Agosto, ] QTD pacientes: 224
#     Cluster 10: 37.05% (435)| [Outras_Comorbidades, Dispneia, SexM, ] QTD pacientes: 1087
#
# Cluster-2 (1066)
# Atributos: Dispneia, Outras_Comorbidades, SexF,
# Compartilhamento de OBJETOS em outros clusters.
# ...

# %%
file = "./output_clustering/20201030_death_res_k15_noNoise_region_obito_y.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,region_obito_mes)
# Out:
# Cluster-1 (1174)
# Atributos: Dispneia, Tosse, SexM, Febre,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)| [Dispneia, Outras_Comorbidades, SexF, ] QTD pacientes: 1066
#     Cluster 3: 45.91% (539)| [DCardiaca, Dispneia, SexM, ] QTD pacientes: 1272
#     Cluster 4: 34.92% (410)| [Tosse, Diabetes, ] QTD pacientes: 1307
#     Cluster 5: 23.25% (273)| [Febre, PORTO ALEGRE - R10, ] QTD pacientes: 943
#     Cluster 6: 8.26% (97)| [Outras_Comorbidades, Julho, Obito_Julho, ] QTD pacientes: 467
#     Cluster 7: 0.00% (0)| [Outros_Sint, Dispneia, SexF, ] QTD pacientes: 569
#     Cluster 8: 11.50% (135)| [Idoso_3, DCardiaca, ] QTD pacientes: 913
#     Cluster 9: 3.92% (46)| [Idoso_2, Obito_Agosto, Agosto, ] QTD pacientes: 224
#     Cluster 10: 37.05% (435)| [Outras_Comorbidades, Dispneia, SexM, ] QTD pacientes: 1087
#     Cluster 11: 21.72% (255)| [Tosse, Idoso_2, ] QTD pacientes: 892
#     Cluster 12: 6.30% (74)| [Idoso_1, Obito_Setembro, ] QTD pacientes: 310
# ...

# %% [markdown]
# Vamos analisar considerando as $regiões$ e $municipios$. As duas análises possuem a informação sobre o $\textbf{mês de óbito}$. A primeira com $\textbf{10 grupos}$ e a segunda com $\textbf{15 grupos}$.

# %%
file = "./output_clustering/20201030_death_res_k10_noNoise_county-region_y.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,municipio_regiao_covid)
chord_vis(columnClusters,rowClusters)
# Out:
# Cluster-1 (1174)
# Atributos: Dispneia, Tosse, SexM, Febre,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)| [Dispneia, Outras_Comorbidades, SexF, ] QTD pacientes: 1066
#     Cluster 3: 45.91% (539)| [DCardiaca, Dispneia, SexM, ] QTD pacientes: 1272
#     Cluster 4: 34.92% (410)| [Tosse, Diabetes, ] QTD pacientes: 1307
#     Cluster 5: 13.80% (162)| [Febre, PORTO ALEGRE - R10, PORTO ALEGRE, ] QTD pacientes: 631
#     Cluster 6: 8.26% (97)| [Outras_Comorbidades, Julho, Obito_Julho, ] QTD pacientes: 467
#     Cluster 7: 0.00% (0)| [Outros_Sint, Dispneia, SexF, ] QTD pacientes: 569
#     Cluster 8: 11.50% (135)| [Idoso_3, DCardiaca, ] QTD pacientes: 913
#     Cluster 9: 3.92% (46)| [Idoso_2, Obito_Agosto, Agosto, ] QTD pacientes: 224
#     Cluster 10: 37.05% (435)| [Febre, Outras_Comorbidades, SexM, ] QTD pacientes: 769
#
# Cluster-2 (1066)
# Atributos: Dispneia, Outras_Comorbidades, SexF,
# Compartilhamento de OBJETOS em outros clusters.
# ...

# %%
file = "./output_clustering/20201030_death_res_k15_noNoise_county-region_y.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,municipio_regiao_covid)
# chord_vis(columnClusters,rowClusters)
# Out:
# Cluster-1 (1174)
# Atributos: Dispneia, Tosse, SexM, Febre,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)| [Dispneia, Outras_Comorbidades, SexF, ] QTD pacientes: 1066
#     Cluster 3: 45.91% (539)| [DCardiaca, Dispneia, SexM, ] QTD pacientes: 1272
#     Cluster 4: 34.92% (410)| [Tosse, Diabetes, ] QTD pacientes: 1307
#     Cluster 5: 13.80% (162)| [Febre, PORTO ALEGRE - R10, PORTO ALEGRE, ] QTD pacientes: 631
#     Cluster 6: 8.26% (97)| [Outras_Comorbidades, Julho, Obito_Julho, ] QTD pacientes: 467
#     Cluster 7: 0.00% (0)| [Outros_Sint, Dispneia, SexF, ] QTD pacientes: 569
#     Cluster 8: 11.50% (135)| [Idoso_3, DCardiaca, ] QTD pacientes: 913
#     Cluster 9: 3.92% (46)| [Idoso_2, Obito_Agosto, Agosto, ] QTD pacientes: 224
#     Cluster 10: 37.05% (435)| [Febre, Outras_Comorbidades, SexM, ] QTD pacientes: 769
#     Cluster 11: 0.00% (0)| [Dispneia, Tosse, SexF, ] QTD pacientes: 981
# ...

# %% [markdown]
# ## Experimento 5 - Pacientes que sobreviveram

# %% [markdown]
# Análise dos 10 grupos mais representativos com o método PaNDa.

# %%
file = "./output_clustering/20201030_rec_res_k10_noNoise.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,covid_dict)

# %%
file = "./output_clustering/20201030_rec_res_k10_noNoise_f.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,covid_dict)
# Out:
# Cluster-1 (61926)
# Atributos: Adulto, Outros_Sint, SexM,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)| [SexF, Adulto, Outros_Sint, ] QTD pacientes: 54806
#     Cluster 3: 22.89% (14172)| [Tosse, Febre, ] QTD pacientes: 51972
#     Cluster 4: 7.46% (4617)| [Agosto, Garganta, ] QTD pacientes: 18176
#     Cluster 5: 0.00% (0)| [SexF, Adulto, ] QTD pacientes: 29801
#     Cluster 6: 26.95% (16691)| [SexM, Julho, ] QTD pacientes: 27516
#     Cluster 7: 7.09% (4389)| [Setembro, Tosse, ] QTD pacientes: 20331
#     Cluster 8: 22.04% (13647)| [Agosto, SexM, ] QTD pacientes: 28522
#     Cluster 9: 10.46% (6480)| [Garganta, PORTO ALEGRE, ] QTD pacientes: 10588
#     Cluster 10: 9.90% (6133)| [Garganta, Tosse, ] QTD pacientes: 32210
#
# Cluster-2 (54806)
# Atributos: SexF, Adulto, Outros_Sint,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 1: 0.00% (0)| [Adulto, Outros_Sint, SexM, ] QTD pacientes: 61926
# ...

# %% [markdown]
# # Resultado filtrado ococlus

# %%
file = "C:/Users/yurin/Documents/my_github/doutorado/pesquisa/datasets/covid19/OCoClusResult_CV19_clean.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,municipio_regiao_covid)
# Out:
# Cluster-1 (1174)
# Atributos: Dispneia, SexM, Febre, Tosse,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)| [Dispneia, Outras_Comorbidades, SexF, ] QTD pacientes: 1066
#     Cluster 3: 45.91% (539)| [Dispneia, SexM, DCardiaca, ] QTD pacientes: 1272
#     Cluster 4: 34.92% (410)| [Diabetes, Tosse, ] QTD pacientes: 1307
#     Cluster 5: 13.80% (162)| [PORTO ALEGRE, Febre, PORTO ALEGRE - R10, ] QTD pacientes: 631
#     Cluster 6: 8.26% (97)| [Obito_Julho, Outras_Comorbidades, Julho, ] QTD pacientes: 467
#     Cluster 7: 0.00% (0)| [Dispneia, Outros_Sint, SexF, ] QTD pacientes: 569
#     Cluster 8: 11.50% (135)| [Idoso_3, DCardiaca, ] QTD pacientes: 913
#     Cluster 9: 3.92% (46)| [Obito_Agosto, Agosto, Idoso_2, ] QTD pacientes: 224
#     Cluster 10: 37.05% (435)| [Outras_Comorbidades, SexM, Febre, ] QTD pacientes: 769
#     Cluster 11: 45.91% (539)| [Dispneia, SexM, DCardiaca, Febre, Tosse, ] QTD pacientes: 539
# ...

# %%
file = "C:/Users/yurin/Documents/my_github/doutorado/pesquisa/datasets/covid19/OCoClusResult_CV19_c2.txt"
df_fimi = pd.read_csv(file, header=None, names=["transation"])
columnClusters,rowClusters = processDocument(df_fimi)
del df_fimi
check_result(columnClusters,rowClusters,municipio_regiao_covid)
# Out:
# Cluster-1 (1174)
# Atributos: Dispneia, SexM, Febre, Tosse,
# Compartilhamento de OBJETOS em outros clusters.
#     Cluster 2: 0.00% (0)| [Dispneia, Outras_Comorbidades, SexF, ] QTD pacientes: 1066
#     Cluster 3: 45.91% (539)| [Dispneia, SexM, DCardiaca, ] QTD pacientes: 1272
#     Cluster 4: 34.92% (410)| [Diabetes, Tosse, ] QTD pacientes: 1307
#     Cluster 5: 13.80% (162)| [PORTO ALEGRE, Febre, PORTO ALEGRE - R10, ] QTD pacientes: 631
#     Cluster 6: 8.26% (97)| [Obito_Julho, Outras_Comorbidades, Julho, ] QTD pacientes: 467
#     Cluster 7: 0.00% (0)| [Dispneia, Outros_Sint, SexF, ] QTD pacientes: 569
#     Cluster 8: 11.50% (135)| [Idoso_3, DCardiaca, ] QTD pacientes: 913
#     Cluster 9: 3.92% (46)| [Obito_Agosto, Agosto, Idoso_2, ] QTD pacientes: 224
#     Cluster 10: 37.05% (435)| [Outras_Comorbidades, SexM, Febre, ] QTD pacientes: 769
#     Cluster 11: 45.91% (539)| [Dispneia, SexM, DCardiaca, Febre, Tosse, ] QTD pacientes: 539
# ...

# %% [markdown]
# # Support methods

# %%
def check_result(columnClusters,rowClusters,map_att_dict):
    nc = len(columnClusters)
    for i in range(nc):
        num_objects = len(set(rowClusters[i]))
        print("Cluster-"+str(i+1)+" ("+str(num_objects)+")")
        print("Atributos: ",end="")
        for ele in columnClusters[i]:
            print(map_att_dict[int(ele)],end=", ")

        print("\nCompartilhamento de OBJETOS em outros clusters.")
        for j in range(nc):
            if i != j:
                print("    Cluster "+str(j+1)+": ",end="")
#                 clusB = len(set(rowClusters[i]))
                qtd_intersect = len(set(rowClusters[j]).intersection(set(rowClusters[i])))
#                 overlap = ((num_objects-(num_objects-qtd_intersect))/len(set(rowClusters[i]).union(set(rowClusters[j]))))*100
                overlap = ((num_objects-(num_objects-qtd_intersect))/num_objects)*100
#                 overlap = ((cluSize-(cluSize-qtd_intersect)))*100
                print("{0:.2f}% ({1:d})".format(overlap,qtd_intersect),end="")
                print("| [",end="")
                for attribute_idx in columnClusters[j]:
                    print(map_att_dict[int(attribute_idx)],end=", ")
                print("]", end=" ")
                print("QTD pacientes: "+str(len(rowClusters[j])))
        print(" ")

# %%
def processDocument(file):
    #print("Executing processDocument() method.")
    size_df = file.shape
    uniqueP = []
    uniqueT = []
    pois_per_cluster = []
    trajs_per_cluster = []
    change = 0
    
    for i in range(size_df[0]):#number of transations
        transationString = file.transation[i].split(' ')
#         print(transationString)
        pois = []
        trajs = []
        for j in range(len(transationString)):
            try:
                tmp = int(transationString[j])
            except:
                tmp = ''
            
            if change == 0:
                if type(tmp) is int:
                    if transationString[j] not in uniqueP:
                        uniqueP.append(transationString[j])
#                         if not pois: # empty
                    pois.append(transationString[j])
#                         print(transationString[j],end="|")
                else:
    #                 print("NO",end=" | ")
                    change = 1
#                     print("")
            else:
                if type(tmp) is int:
                    if transationString[j] not in uniqueT:
                        uniqueT.append(transationString[j])
                    trajs.append(transationString[j])
                else:
    #                 print("NO",end=" | ")
                    if change == 1:
                        change = 2
                        tmp = re.split('\[| |\]',transationString[j])
                        #print("1-tmp:"+str(tmp))
                        if tmp[1] not in uniqueT:
                            uniqueT.append(tmp[1])
                        trajs.append(tmp[1])
                    else:
                        tmp = re.split('\[| |\]',transationString[j])
                        #print("2-tmp:"+str(tmp))
                        if tmp[0] not in uniqueT:
                            uniqueT.append(tmp[0])
                        trajs.append(tmp[0])
                        change = 0
        pois_per_cluster.append(pois)
        trajs_per_cluster.append(trajs)

#     print('Number of unique elements: ',len(uniqueElements))
#     print("P per Clusters: "+str(pois_per_cluster))
#     print("T per Clusters: "+str(trajs_per_cluster))
    return pois_per_cluster,trajs_per_cluster

# %%
def chord_vis(colClus,rowClus):
# Só da para ver até 20 cores    
    num_of_cluster = len(colClus)
    nodes = []
    for i in range(num_of_cluster):
        nodes.append('G'+str(i+1))
    print("New nodes: ",nodes)
    
    links = np.zeros((num_of_cluster,num_of_cluster),dtype=int)
    print("Size links:",links.shape)
    
    for i in range(num_of_cluster):
        tmp = set(rowClus[i])
        for j in range(num_of_cluster):
            if i != j:
                obj_intenserction_qtd = len(set(rowClus[i]).intersection(set(rowClus[j])))
                if obj_intenserction_qtd > 1:
                    links[i][j] = obj_intenserction_qtd
            else:
                for z in range(num_of_cluster):
                    if i != z:
                        tmp.difference_update(rowClus[z])
                if len(tmp) > 1:
                    links[i][j] = len(tmp)
    
    fig = plt.figure(figsize=(6,6))
    ax = plt.axes([0,0,1,1])
    nodePos = chordDiagram(links, ax)
    ax.axis('off')
#     prop = dict(fontsize=16*0.8, ha='center', va='center')
    prop = dict(fontsize=16*0.8, ha='center', va='center')
    for i in range(num_of_cluster):
        ax.text(nodePos[i][0], nodePos[i][1], nodes[i], rotation=nodePos[i][2], **prop)

# %%
heatmap_vis(columnClusters,rowClusters)

# %%
heatmap_accumulative_vis(columnClusters,rowClusters)
# Out:
# 0 1: 0
# 0 2: 539
# 0 3: 241
# 0 4: 39
# 0 5: 2
# 0 6: 0
# 0 7: 1
# 0 8: 0
# 0 9: 0
# 1 0: 0
# 1 2: 0
# 1 3: 258
# 1 4: 20
# 1 5: 3
# 1 6: 0
# 1 7: 0
# 1 8: 0
# 1 9: 0
# 2 0: 539
# 2 1: 0
# 2 3: 241
# 2 4: 39
# 2 5: 2
# 2 6: 0
# 2 7: 1
# 2 8: 0
# 2 9: 0
# 3 0: 410
# 3 1: 0
# 3 2: 241
# 3 4: 39
# 3 5: 2
# 3 6: 0
# 3 7: 1
# 3 8: 0
# 3 9: 0
# 4 0: 162
# 4 1: 0
# 4 2: 75
# 4 3: 39
# 4 5: 2
# 4 6: 0
# 4 7: 1
# 4 8: 0
# 4 9: 0
# 5 0: 97
# 5 1: 0
# 5 2: 40
# 5 3: 15
# 5 4: 2
# 5 6: 0
# 5 7: 1
# 5 8: 0
# 5 9: 0
# 6 0: 0
# 6 1: 365
# 6 2: 0
# 6 3: 80
# 6 4: 8
# 6 5: 0
# 6 7: 2
# 6 8: 0
# 6 9: 0
# 7 0: 135
# 7 1: 0
# 7 2: 135
# 7 3: 41
# 7 4: 10
# 7 5: 1
# 7 6: 0
# 7 8: 0
# 7 9: 0
# 8 0: 46
# 8 1: 0
# 8 2: 29
# 8 3: 12
# 8 4: 1
# 8 5: 0
# 8 6: 0
# 8 7: 0
# 8 9: 0
# 9 0: 435
# 9 1: 0
# 9 2: 185
# 9 3: 79
# 9 4: 21
# 9 5: 0
# 9 6: 0
# 9 7: 3
# 9 8: 0

# %%
def heatmap_vis(colClus,rowClus):
    f, axes = plt.subplots(figsize=(4,5.5))
    num_of_cluster = len(colClus)
    nodes = []
    for i in range(num_of_cluster):
        nodes.append('G'+str(i+1))
#     print("New nodes: ",nodes)
    
    links = np.zeros((num_of_cluster,num_of_cluster),dtype=int)
#     print("Size links:",links.shape)
    
    for i in range(num_of_cluster):
        tmp = set(rowClus[i])
        for j in range(num_of_cluster):
            if i != j:
                obj_intenserction_qtd = len(set(rowClus[i]).intersection(set(rowClus[j])))
                if obj_intenserction_qtd > 0:
                    links[i][j] = obj_intenserction_qtd
            else:
                # seraching for exclusive elements in the clusters
                for z in range(num_of_cluster):
                    if i != z:
                        tmp.difference_update(rowClus[z])
                if len(tmp) > 0:
                    links[i][j] = len(tmp)

    # Generate a mask for the upper triangle
    mask = np.triu(np.ones_like(links, dtype=bool))
#     mask = np.zeros_like(links)
    mask[np.diag_indices_from(mask)] = False
    
    # Generate a custom diverging colormap
#     cmap = sb.diverging_palette(220, 20, n=10, as_cmap=True)
    cmap = sb.diverging_palette(240, 10, n=11, as_cmap=True)
    
#     ax = sb.heatmap(m1, xticklabels=2, yticklabels=False)
    #colors: [coolwarm,Reds]
#     ax = sb.heatmap(links,xticklabels=nodes,yticklabels=nodes,cmap="Reds",annot=True, fmt="d",
    ax = sb.heatmap(links,mask=mask,xticklabels=nodes,yticklabels=nodes,cmap="Reds",annot=True, fmt="d",
#     ax = sb.heatmap(links,mask=mask,xticklabels=nodes,yticklabels=nodes,cmap=cmap,
                    cbar_kws={"orientation": "horizontal",'label': 'Number of objects'})
#     ax.set_yticklabels(ax.get_yticklabels(), rotation=30)

# %%
def heatmap_accumulative_vis(colClus,rowClus):
    '''
    Essa visualização considera o número de elementos compartilhados do cluster referência i no acumulativo sequencial
    com o cluster j.
    Exemplo:
    grupos-> g1,g2 e g3
    g1 = g1 - g1.intersection.g2_g3
    g2 = g2.intersection.g1
    g3 = g3.intersection.g1_g2
    '''
    f, axes = plt.subplots(figsize=(4,5.5))
    num_of_cluster = len(colClus)
    nodes = []
    for i in range(num_of_cluster):
        nodes.append('G'+str(i+1))
    
    links = np.zeros((num_of_cluster,num_of_cluster),dtype=int)
    
    for i in range(num_of_cluster):
        tmp = set(rowClus[i])
        obj_intenserction_qtd = set(rowClus[i])
        tmp_acc = obj_intenserction_qtd.copy()
        for j in range(num_of_cluster):
            if i != j:
#                 tmp_acc = obj_intenserction_qtd.copy()
                obj_intenserction_qtd = obj_intenserction_qtd.intersection(set(rowClus[j]))
                print(i,j,end=": ")
                print(len(obj_intenserction_qtd))
                if len(obj_intenserction_qtd) != 0:
                    links[i][j] = len(obj_intenserction_qtd)
                    tmp_acc = obj_intenserction_qtd.copy()
                else:
                    obj_intenserction_qtd = tmp_acc.copy()
#             else:
#                 for z in range(num_of_cluster):
#                     if i != z:
#                         tmp.difference_update(rowClus[z])
#                 if len(tmp) > 0:
#                     links[i][j] = len(tmp)

    # Generate a mask for the upper triangle
    mask = np.triu(np.ones_like(links, dtype=bool))
    
    # Generate a custom diverging colormap
#     cmap = sb.diverging_palette(220, 20, n=10, as_cmap=True)
#     cmap = sb.diverging_palette(240, 10, n=11, as_cmap=True)
    cmap = sb.diverging_palette(240, 10, n=num_of_cluster+1, as_cmap=True)
    
#     ax = sb.heatmap(m1, xticklabels=2, yticklabels=False)
    #colors: [coolwarm,Reds]
    ax = sb.heatmap(links,xticklabels=nodes,yticklabels=nodes,cmap="Reds",
#     ax = sb.heatmap(links,mask=mask,xticklabels=nodes,yticklabels=nodes,cmap="Reds",
#     ax = sb.heatmap(links,mask=mask,xticklabels=nodes,yticklabels=nodes,cmap=cmap,
                    cbar_kws={"orientation": "horizontal",'label': 'Number of sharable objects'})
#     ax.set_yticklabels(ax.get_yticklabels(), rotation=30)

# %%
###################
# chord diagram
# https://github.com/fengwangPhysics/matplotlib-chord-diagram
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches

import numpy as np

LW = 0.3

def polar2xy(r, theta):
    return np.array([r*np.cos(theta), r*np.sin(theta)])

def hex2rgb(c):
    return tuple(int(c[i:i+2], 16)/256.0 for i in (1, 3 ,5))

def IdeogramArc(start=0, end=60, radius=1.0, width=0.2, ax=None, color=(1,0,0)):
    # start, end should be in [0, 360)
    if start > end:
        start, end = end, start
    start *= np.pi/180.
    end *= np.pi/180.
    # optimal distance to the control points
    # https://stackoverflow.com/questions/1734745/how-to-create-circle-with-b%C3%A9zier-curves
    opt = 4./3. * np.tan((end-start)/ 4.) * radius
    inner = radius*(1-width)
    verts = [
        polar2xy(radius, start),
        polar2xy(radius, start) + polar2xy(opt, start+0.5*np.pi),
        polar2xy(radius, end) + polar2xy(opt, end-0.5*np.pi),
        polar2xy(radius, end),
        polar2xy(inner, end),
        polar2xy(inner, end) + polar2xy(opt*(1-width), end-0.5*np.pi),
        polar2xy(inner, start) + polar2xy(opt*(1-width), start+0.5*np.pi),
        polar2xy(inner, start),
        polar2xy(radius, start),
        ]

    codes = [Path.MOVETO,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.LINETO,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CLOSEPOLY,
             ]

    if ax == None:
        return verts, codes
    else:
        path = Path(verts, codes)
        patch = patches.PathPatch(path, facecolor=color+(0.5,), edgecolor=color+(0.4,), lw=LW)
        ax.add_patch(patch)


def ChordArc(start1=0, end1=60, start2=180, end2=240, radius=1.0, chordwidth=0.7, ax=None, color=(1,0,0)):
    # start, end should be in [0, 360)
    if start1 > end1:
        start1, end1 = end1, start1
    if start2 > end2:
        start2, end2 = end2, start2
    start1 *= np.pi/180.
    end1 *= np.pi/180.
    start2 *= np.pi/180.
    end2 *= np.pi/180.
    opt1 = 4./3. * np.tan((end1-start1)/ 4.) * radius
    opt2 = 4./3. * np.tan((end2-start2)/ 4.) * radius
    rchord = radius * (1-chordwidth)
    verts = [
        polar2xy(radius, start1),
        polar2xy(radius, start1) + polar2xy(opt1, start1+0.5*np.pi),
        polar2xy(radius, end1) + polar2xy(opt1, end1-0.5*np.pi),
        polar2xy(radius, end1),
        polar2xy(rchord, end1),
        polar2xy(rchord, start2),
        polar2xy(radius, start2),
        polar2xy(radius, start2) + polar2xy(opt2, start2+0.5*np.pi),
        polar2xy(radius, end2) + polar2xy(opt2, end2-0.5*np.pi),
        polar2xy(radius, end2),
        polar2xy(rchord, end2),
        polar2xy(rchord, start1),
        polar2xy(radius, start1),
        ]

    codes = [Path.MOVETO,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             ]

    if ax == None:
        return verts, codes
    else:
        path = Path(verts, codes)
        patch = patches.PathPatch(path, facecolor=color+(0.5,), edgecolor=color+(0.4,), lw=LW)
        ax.add_patch(patch)

def selfChordArc(start=0, end=60, radius=1.0, chordwidth=0.7, ax=None, color=(1,0,0)):
    # start, end should be in [0, 360)
    if start > end:
        start, end = end, start
    start *= np.pi/180.
    end *= np.pi/180.
    opt = 4./3. * np.tan((end-start)/ 4.) * radius
    rchord = radius * (1-chordwidth)
    verts = [
        polar2xy(radius, start),
        polar2xy(radius, start) + polar2xy(opt, start+0.5*np.pi),
        polar2xy(radius, end) + polar2xy(opt, end-0.5*np.pi),
        polar2xy(radius, end),
        polar2xy(rchord, end),
        polar2xy(rchord, start),
        polar2xy(radius, start),
        ]

    codes = [Path.MOVETO,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             Path.CURVE4,
             ]

    if ax == None:
        return verts, codes
    else:
        path = Path(verts, codes)
        patch = patches.PathPatch(path, facecolor=color+(0.5,), edgecolor=color+(0.4,), lw=LW)
        ax.add_patch(patch)

def chordDiagram(X, ax, colors=None, width=0.1, pad=2, chordwidth=0.7):
    """Plot a chord diagram
    Parameters
    ----------
    X :
        flux data, X[i, j] is the flux from i to j
    ax :
        matplotlib `axes` to show the plot
    colors : optional
        user defined colors in rgb format. Use function hex2rgb() to convert hex color to rgb color. Default: d3.js category10
    width : optional
        width/thickness of the ideogram arc
    pad : optional
        gap pad between two neighboring ideogram arcs, unit: degree, default: 2 degree
    chordwidth : optional
        position of the control points for the chords, controlling the shape of the chords
    """
    # X[i, j]:  i -> j
    x = X.sum(axis = 1) # sum over rows
    ax.set_xlim(-1.1, 1.1)
    ax.set_ylim(-1.1, 1.1)

    if colors is None:
        if len(x) <= 10:
            # use d3.js category10 https://github.com/d3/d3-3.x-api-reference/blob/master/Ordinal-Scales.md#category10
            colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
                      '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
        elif len(x) <= 20:
            # use d3.js category20 https://github.com/d3/d3-3.x-api-reference/blob/master/Ordinal-Scales.md#category20
            colors = ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c', '#98df8a', '#d62728', '#ff9896',
                      '#9467bd', '#c5b0d5', '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f', '#c7c7c7',
                      '#bcbd22', '#dbdb8d','#17becf', '#9edae5']
        else:
#             print('x is too large! Use x smaller than 10')
            print('x is too large! Use x up to 20')
        
        colors = [hex2rgb(colors[i]) for i in range(len(x))]

    # find position for each start and end
    y = x/np.sum(x).astype(float) * (360 - pad*len(x))

    pos = {}
    arc = []
    nodePos = []
    start = 0
    for i in range(len(x)):
        end = start + y[i]
        arc.append((start, end))
        angle = 0.5*(start+end)
        #print(start, end, angle)
        if -30 <= angle <= 210:
            angle -= 90
        else:
            angle -= 270
        nodePos.append(tuple(polar2xy(1.1, 0.5*(start+end)*np.pi/180.)) + (angle,))
        z = (X[i, :]/x[i].astype(float)) * (end - start)
        ids = np.argsort(z)
        z0 = start
        for j in ids:
            pos[(i, j)] = (z0, z0+z[j])
            z0 += z[j]
        start = end + pad

    for i in range(len(x)):
        start, end = arc[i]
        IdeogramArc(start=start, end=end, radius=1.0, ax=ax, color=colors[i], width=width)
        start, end = pos[(i,i)]
        selfChordArc(start, end, radius=1.-width, color=colors[i], chordwidth=chordwidth*0.7, ax=ax)
#         selfChordArc(start, end, radius=1.-width, color=(0, 0, 0), chordwidth=chordwidth*0.7, ax=ax)
        
        #posso mudar aqui para corrigir a cor da linha em relação a proporção do FROM and TO
        for j in range(i):
            color = colors[i]
            if X[i, j] > X[j, i]:
                color = colors[j]
            start1, end1 = pos[(i,j)]
            start2, end2 = pos[(j,i)]
            ChordArc(start1, end1, start2, end2,
#                      radius=1.-width, color=colors[i], chordwidth=chordwidth, ax=ax)
                     radius=1.-width, color=(0, 0, 0), chordwidth=chordwidth, ax=ax)

    #print(nodePos)
    return nodePos

# ##################################
# if __name__ == "__main__":
#     fig = plt.figure(figsize=(6,6))
#     flux = np.array([[11975,  5871, 8916, 2868],
#       [ 1951, 10048, 2060, 6171],
#       [ 8010, 16145, 8090, 8045],
#       [ 1013,   990,  940, 6907]
#     ])

#     ax = plt.axes([0,0,1,1])

#     #nodePos = chordDiagram(flux, ax, colors=[hex2rgb(x) for x in ['#666666', '#66ff66', '#ff6666', '#6666ff']])
#     nodePos = chordDiagram(flux, ax)
#     ax.axis('off')
#     prop = dict(fontsize=16*0.8, ha='center', va='center')
#     nodes = ['non-crystal', 'FCC', 'HCP', 'BCC']
#     for i in range(4):
#         ax.text(nodePos[i][0], nodePos[i][1], nodes[i], rotation=nodePos[i][2], **prop)

# #     plt.savefig("example.png", dpi=600,
# #             transparent=True,
# #             bbox_inches='tight', pad_inches=0.02)

# %% [markdown]
# Mapping from id to att. Dataset: FoursquareNY_top10

# %%
top10_dict = {
0: 'Strip_Club',
1: 'American_Restaurant',
2: 'Pool',
3: 'Other_Nightlife',
4: 'Speakeasy',
5: 'Music_Venue',
6: 'Park',
7: 'Bus_Line',
8: 'Hotel',
9: 'Bank',
10: 'Post_Office',
11: 'Elementary_School',
12: 'Coffee_Shop',
13: 'Cuban_Restaurant',
14: 'Restaurant',
15: 'Donut_Shop',
16: 'Pizza_Place',
17: 'High_School',
18: 'Home_(private)',
19: 'Building',
20: "Doctor's_Office",
21: 'Office',
22: 'Gas_Station',
23: 'Seafood_Restaurant',
24: 'Italian_Restaurant',
25: 'Government_Building',
26: 'Mexican_Restaurant',
27: 'Sports_Bar',
28: 'Meeting_Room',
29: 'Church',
30: 'Museum',
31: 'Airport_Terminal',
32: 'Automotive_Shop',
33: 'Gift_Shop',
34: 'Pharmacy',
35: 'Cafe',
36: 'Beach',
37: 'Library',
38: 'Hardware_Store',
39: 'Airport_Tram',
40: 'Burger_Joint',
41: 'Farm',
42: 'Airport_Gate',
43: 'Residential_Building_(Apartment_/_Condo)',
44: 'Fast_Food_Restaurant',
45: 'Arts_&_Crafts_Store',
46: 'Salon_/_Barbershop',
47: 'Lounge',
48: 'Ice_Cream_Shop',
49: 'Gymnastics_Gym',
50: 'Breakfast_Spot',
51: 'Cocktail_Bar',
52: 'General_Entertainment',
53: 'Animal_Shelter',
54: 'Music_Store',
55: 'Sushi_Restaurant',
56: 'Gym',
57: 'German_Restaurant',
58: 'Hookah_Bar',
59: 'Bridge',
60: 'Steakhouse',
61: 'Bus_Stop',
62: 'Clothing_Store',
63: 'Golf_Course',
64: 'Nightclub',
65: 'Furniture_/_Home_Store',
66: 'Other_Repair_Shop',
67: 'Gym_/_Fitness_Center',
68: 'Cosmetics_Shop',
69: 'Medical_Center',
70: 'Gourmet_Shop',
71: 'Convenience_Store',
72: 'Caribbean_Restaurant',
73: "Dentist's_Office",
74: 'Supermarket',
75: 'Smoke_Shop',
76: 'Metro_Station',
77: 'Gay_Bar',
78: 'Electronics_Store',
79: 'Paper_/_Office_Supplies_Store',
80: 'Bus_Station',
81: 'Radio_Station',
82: 'Deli_/_Bodega',
83: 'Miscellaneous_Shop',
84: 'Southern_/_Soul_Food_Restaurant',
85: 'Discount_Store',
86: 'Grocery_Store',
87: 'Hockey_Arena',
88: 'Sandwich_Place',
89: 'Plaza',
90: 'Cafeteria',
91: 'Chinese_Restaurant',
92: 'Optical_Shop',
93: 'Bakery',
94: 'Bagel_Shop',
95: 'Food_Truck',
96: 'Laundry_Service',
97: 'Food_&_Drink_Shop',
98: 'Train',
99: 'Diner',
100: 'Fair',
101: 'Wine_Bar',
102: 'Basketball_Court',
103: 'Mobile_Phone_Shop',
104: 'Cemetery',
105: 'Voting_Booth',
106: 'Funeral_Home',
107: 'Storage_Facility',
108: 'Performing_Arts_Venue',
109: 'Shoe_Store',
110: 'Camera_Store',
111: 'Latin_American_Restaurant',
112: 'Fried_Chicken_Joint',
113: 'Field',
114: 'Housing_Development',
115: 'Financial_or_Legal_Service',
116: 'Soccer_Stadium',
117: 'Scenic_Lookout',
118: 'Art_Gallery',
119: 'Dive_Bar',
120: 'Nail_Salon',
121: 'Movie_Theater',
122: 'Dog_Run',
123: 'Racetrack',
124: 'Baseball_Stadium',
125: 'Tech_Startup',
126: 'Market',
127: 'Dessert_Shop',
128: "Women's_Store",
129: 'Frozen_Yogurt_Shop',
130: 'Fish_Market',
131: 'BBQ_Joint',
132: 'Bar',
133: 'Department_Store',
134: 'Garden',
135: 'Distillery',
136: 'Wine_Shop',
137: 'Chiropractor',
138: 'Board_Shop',
139: 'Basketball_Stadium',
140: 'Juice_Bar',
141: 'French_Restaurant',
142: 'Concert_Hall',
143: 'Pub',
144: 'Sporting_Goods_Shop',
145: 'Mediterranean_Restaurant',
146: 'Wings_Joint',
147: 'Parking',
148: 'School',
149: 'Noodle_House',
150: 'New_American_Restaurant',
151: 'College_History_Building',
152: 'Monument_/_Landmark',
153: 'Beer_Garden',
154: 'Gastropub',
155: 'Art_Museum',
156: 'Shopping_Mall',
157: 'Falafel_Restaurant',
158: 'Spa',
159: 'Tea_Room',
160: 'Soup_Place',
161: 'Spanish_Restaurant',
162: 'Liquor_Store',
163: 'Car_Wash',
164: 'Tunnel',
165: 'Multiplex',
166: 'College_Academic_Building',
167: 'Luggage_Store',
168: 'Japanese_Restaurant',
169: 'Toll_Plaza',
170: 'Pier',
171: 'Big_Box_Store',
172: 'Salad_Place',
173: 'Light_Rail_Station',
174: 'Theater',
175: 'Rock_Club',
176: 'Chocolate_Shop',
177: 'Boutique',
178: 'Asian_Restaurant',
179: 'Bookstore',
180: 'Farmers_Market',
181: 'Brazilian_Restaurant',
182: 'Outdoor_Sculpture',
183: 'Thai_Restaurant',
184: 'Flea_Market',
185: 'Resort',
186: 'Tapas_Restaurant',
187: 'Karaoke_Bar',
188: 'Street_Food_Gathering',
189: 'Hot_Dog_Joint',
190: 'Comedy_Club',
191: 'Dance_Studio',
192: 'Fraternity_House',
193: 'Playground',
194: 'Hotel_Bar',
195: 'Brewery',
196: 'Peruvian_Restaurant',
197: 'Coworking_Space',
198: 'Bubble_Tea_Shop',
199: 'South_American_Restaurant',
200: 'Austrian_Restaurant',
201: 'Lingerie_Store',
202: 'Israeli_Restaurant',
203: 'College_Administrative_Building',
204: 'Yoga_Studio',
205: 'College_Arts_Building',
206: 'Pie_Shop',
207: 'Science_Museum',
208: 'Historic_Site',
209: 'Burrito_Place',
210: 'Airport',
211: 'Korean_Restaurant',
212: 'Thrift_/_Vintage_Store',
213: 'Russian_Restaurant',
214: 'Roof_Deck',
215: 'College_Classroom',
216: 'Event_Space',
217: 'Cupcake_Shop',
218: 'College_Bookstore',
219: 'Pet_Store',
220: 'Video_Game_Store',
221: 'Supplement_Shop',
222: 'Colombian_Restaurant',
223: 'Festival',
224: 'Cajun_/_Creole_Restaurant',
225: 'Kitchen_Supply_Store',
226: 'Irish_Pub',
227: 'Jazz_Club',
228: 'Indie_Movie_Theater',
229: 'Border_Crossing',
230: 'Vegetarian_/_Vegan_Restaurant',
231: 'Candy_Store',
232: 'Toy_/_Game_Store',
233: 'Spiritual_Center',
234: 'Indian_Restaurant',
235: 'Greek_Restaurant',
236: 'Food_Court',
237: 'Belgian_Restaurant',
238: 'Temple',
239: 'Business_Service',
240: 'City_Hall',
241: 'IT_Services',
242: 'Corporate_Cafeteria',
243: 'University',
244: 'Czech_Restaurant',
245: 'English_Restaurant',
246: 'Taco_Place',
247: 'Memorial_Site',
248: 'Synagogue',
249: 'Indie_Theater',
250: 'Rest_Area',
251: 'Platform',
252: 'Aquarium',
253: 'Theme_Park',
254: 'Auto_Dealership',
255: 'Theme_Park_Ride_/_Attraction',
256: 'Public_Art',
257: 'Campground',
258: 'Newsstand',
259: 'Casino',
260: 'Check_Cashing_Service',
261: 'Shop_&_Service',
262: "Men's_Store",
263: 'Skating_Rink',
264: 'Bowling_Alley',
265: 'Cheese_Shop',
266: 'Butcher',
267: 'Airport_Lounge',
268: 'Turkish_Restaurant',
269: 'Snack_Place',
270: 'Dumpling_Restaurant',
271: 'Australian_Restaurant',
272: 'Vietnamese_Restaurant',
273: 'Shanghai_Restaurant',
274: 'Advertising_Agency',
275: 'Outdoors_&_Recreation',
276: 'Sake_Bar',
277: 'Eastern_European_Restaurant',
278: 'Portuguese_Restaurant',
279: 'Filipino_Restaurant',
280: 'Street_Fair',
281: 'Middle_Eastern_Restaurant',
282: 'Pakistani_Restaurant',
283: 'Beer_Store',
284: 'Empanada_Restaurant',
285: 'Scandinavian_Restaurant',
286: 'Christmas_Market',
287: 'Trade_School',
288: 'Cable_Car',
289: 'Swiss_Restaurant',
290: 'Assisted_Living',
291: 'Whisky_Bar',
292: 'Football_Stadium',
293: 'Ramen_Restaurant',
294: 'Track',
295: 'Convention_Center',
296: 'College_Technology_Building',
297: 'Baseball_Field',
298: 'Island',
299: 'Fire_Station',
300: 'Bike_Shop',
301: 'Arcade',
302: 'Credit_Union',
303: 'Harbor_/_Marina',
304: 'Courthouse',
305: 'Waterfront',
306: 'Trail',
307: 'Music_School',
308: 'Warehouse_Store',
309: 'Hotpot_Restaurant'
}

# %% [markdown]
# Covid_dict é um dicinário com o mapping de cada coluna com o atributo que foi presente para um dado paciente no dataset. Possui 549 atributos nessa configuração.

# %%
covid_dict = {
0: 'ACEGUÁ',
1: 'ÁGUA SANTA',
2: 'AGUDO',
3: 'AJURICABA',
4: 'ALECRIM',
5: 'ALEGRETE',
6: 'ALEGRIA',
7: 'ALMIRANTE TAMANDARÉ DO SUL',
8: 'ALPESTRE',
9: 'ALTO ALEGRE',
10: 'ALTO FELIZ',
11: 'ALVORADA',
12: 'AMARAL FERRADOR',
13: 'AMETISTA DO SUL',
14: 'ANDRÉ DA ROCHA',
15: 'ANTA GORDA',
16: 'ANTÔNIO PRADO',
17: 'ARAMBARÉ',
18: 'ARARICÁ',
19: 'ARATIBA',
20: 'ARROIO DO MEIO',
21: 'ARROIO DO SAL',
22: 'ARROIO DO PADRE',
23: 'ARROIO DOS RATOS',
24: 'ARROIO DO TIGRE',
25: 'ARROIO GRANDE',
26: 'ARVOREZINHA',
27: 'AUGUSTO PESTANA',
28: 'ÁUREA',
29: 'BAGÉ',
30: 'BALNEÁRIO PINHAL',
31: 'BARÃO',
32: 'BARÃO DE COTEGIPE',
33: 'BARÃO DO TRIUNFO',
34: 'BARRACÃO',
35: 'BARRA DO GUARITA',
36: 'BARRA DO QUARAÍ',
37: 'BARRA DO RIBEIRO',
38: 'BARRA DO RIO AZUL',
39: 'BARRA FUNDA',
40: 'BARROS CASSAL',
41: 'BENJAMIN CONSTANT DO SUL',
42: 'BENTO GONÇALVES',
43: 'BOA VISTA DAS MISSÕES',
44: 'BOA VISTA DO BURICÁ',
45: 'BOA VISTA DO CADEADO',
46: 'BOA VISTA DO INCRA',
47: 'BOA VISTA DO SUL',
48: 'BOM JESUS',
49: 'BOM PRINCÍPIO',
50: 'BOM PROGRESSO',
51: 'BOM RETIRO DO SUL',
52: 'BOQUEIRÃO DO LEÃO',
53: 'BOSSOROCA',
54: 'BOZANO',
55: 'BRAGA',
56: 'BROCHIER',
57: 'BUTIÁ',
58: 'CAÇAPAVA DO SUL',
59: 'CACEQUI',
60: 'CACHOEIRA DO SUL',
61: 'CACHOEIRINHA',
62: 'CACIQUE DOBLE',
63: 'CAIBATÉ',
64: 'CAIÇARA',
65: 'CAMAQUÃ',
66: 'CAMARGO',
67: 'CAMBARÁ DO SUL',
68: 'CAMPESTRE DA SERRA',
69: 'CAMPINA DAS MISSÕES',
70: 'CAMPINAS DO SUL',
71: 'CAMPO BOM',
72: 'CAMPO NOVO',
73: 'CAMPOS BORGES',
74: 'CANDELÁRIA',
75: 'CÂNDIDO GODÓI',
76: 'CANDIOTA',
77: 'CANELA',
78: 'CANGUÇU',
79: 'CANOAS',
80: 'CANUDOS DO VALE',
81: 'CAPÃO BONITO DO SUL',
82: 'CAPÃO DA CANOA',
83: 'CAPÃO DO CIPÓ',
84: 'CAPÃO DO LEÃO',
85: 'CAPIVARI DO SUL',
86: 'CAPELA DE SANTANA',
87: 'CAPITÃO',
88: 'CARAZINHO',
89: 'CARAÁ',
90: 'CARLOS BARBOSA',
91: 'CARLOS GOMES',
92: 'CASCA',
93: 'CASEIROS',
94: 'CATUÍPE',
95: 'CAXIAS DO SUL',
96: 'CENTENÁRIO',
97: 'CERRITO',
98: 'CERRO GRANDE',
99: 'CERRO GRANDE DO SUL',
100: 'CERRO LARGO',
101: 'CHAPADA',
102: 'CHARQUEADAS',
103: 'CHARRUA',
104: 'CHIAPETTA',
105: 'CHUÍ',
106: 'CHUVISCA',
107: 'CIDREIRA',
108: 'CIRÍACO',
109: 'COLINAS',
110: 'COLORADO',
111: 'CONDOR',
112: 'CONSTANTINA',
113: 'COQUEIRO BAIXO',
114: 'COQUEIROS DO SUL',
115: 'CORONEL BARROS',
116: 'CORONEL BICACO',
117: 'CORONEL PILAR',
118: 'COTIPORÃ',
119: 'COXILHA',
120: 'CRISSIUMAL',
121: 'CRISTAL',
122: 'CRISTAL DO SUL',
123: 'CRUZ ALTA',
124: 'CRUZALTENSE',
125: 'CRUZEIRO DO SUL',
126: 'DAVID CANABARRO',
127: 'DERRUBADAS',
128: 'DEZESSEIS DE NOVEMBRO',
129: 'DILERMANDO DE AGUIAR',
130: 'DOIS IRMÃOS',
131: 'DOIS IRMÃOS DAS MISSÕES',
132: 'DOIS LAJEADOS',
133: 'DOM FELICIANO',
134: 'DOM PEDRO DE ALCÂNTARA',
135: 'DOM PEDRITO',
136: 'DONA FRANCISCA',
137: 'DOUTOR MAURÍCIO CARDOSO',
138: 'DOUTOR RICARDO',
139: 'ELDORADO DO SUL',
140: 'ENCANTADO',
141: 'ENCRUZILHADA DO SUL',
142: 'ENGENHO VELHO',
143: 'ENTRE-IJUÍS',
144: 'ENTRE RIOS DO SUL',
145: 'EREBANGO',
146: 'ERECHIM',
147: 'ERNESTINA',
148: 'HERVAL',
149: 'ERVAL GRANDE',
150: 'ERVAL SECO',
151: 'ESMERALDA',
152: 'ESPERANÇA DO SUL',
153: 'ESPUMOSO',
154: 'ESTAÇÃO',
155: 'ESTÂNCIA VELHA',
156: 'ESTEIO',
157: 'ESTRELA',
158: 'ESTRELA VELHA',
159: 'EUGÊNIO DE CASTRO',
160: 'FAGUNDES VARELA',
161: 'FARROUPILHA',
162: 'FAXINAL DO SOTURNO',
163: 'FAXINALZINHO',
164: 'FAZENDA VILANOVA',
165: 'FELIZ',
166: 'FLORES DA CUNHA',
167: 'FLORIANO PEIXOTO',
168: 'FONTOURA XAVIER',
169: 'FORMIGUEIRO',
170: 'FORQUETINHA',
171: 'FORTALEZA DOS VALOS',
172: 'FREDERICO WESTPHALEN',
173: 'GARIBALDI',
174: 'GAURAMA',
175: 'GENERAL CÂMARA',
176: 'GENTIL',
177: 'GETÚLIO VARGAS',
178: 'GIRUÁ',
179: 'GLORINHA',
180: 'GRAMADO',
181: 'GRAMADO DOS LOUREIROS',
182: 'GRAMADO XAVIER',
183: 'GRAVATAÍ',
184: 'GUABIJU',
185: 'GUAÍBA',
186: 'GUAPORÉ',
187: 'GUARANI DAS MISSÕES',
188: 'HARMONIA',
189: 'HERVEIRAS',
190: 'HORIZONTINA',
191: 'HULHA NEGRA',
192: 'HUMAITÁ',
193: 'IBARAMA',
194: 'IBIAÇÁ',
195: 'IBIRAIARAS',
196: 'IBIRAPUITÃ',
197: 'IBIRUBÁ',
198: 'IGREJINHA',
199: 'IJUÍ',
200: 'ILÓPOLIS',
201: 'IMBÉ',
202: 'IMIGRANTE',
203: 'INDEPENDÊNCIA',
204: 'INHACORÁ',
205: 'IPÊ',
206: 'IPIRANGA DO SUL',
207: 'IRAÍ',
208: 'ITAARA',
209: 'ITACURUBI',
210: 'ITAPUCA',
211: 'ITAQUI',
212: 'ITATI',
213: 'ITATIBA DO SUL',
214: 'IVORÁ',
215: 'IVOTI',
216: 'JABOTICABA',
217: 'JACUIZINHO',
218: 'JACUTINGA',
219: 'JAGUARÃO',
220: 'JAGUARI',
221: 'JAQUIRANA',
222: 'JARI',
223: 'JÓIA',
224: 'JÚLIO DE CASTILHOS',
225: 'LAGOA BONITA DO SUL',
226: 'LAGOÃO',
227: 'LAGOA DOS TRÊS CANTOS',
228: 'LAGOA VERMELHA',
229: 'LAJEADO',
230: 'LAJEADO DO BUGRE',
231: 'LAVRAS DO SUL',
232: 'LIBERATO SALZANO',
233: 'LINDOLFO COLLOR',
234: 'LINHA NOVA',
235: 'MACHADINHO',
236: 'MAÇAMBARÁ',
237: 'MAMPITUBA',
238: 'MANOEL VIANA',
239: 'MAQUINÉ',
240: 'MARATÁ',
241: 'MARAU',
242: 'MARCELINO RAMOS',
243: 'MARIANA PIMENTEL',
244: 'MARIANO MORO',
245: 'MARQUES DE SOUZA',
246: 'MATA',
247: 'MATO CASTELHANO',
248: 'MATO LEITÃO',
249: 'MATO QUEIMADO',
250: 'MAXIMILIANO DE ALMEIDA',
251: 'MINAS DO LEÃO',
252: 'MIRAGUAÍ',
253: 'MONTAURI',
254: 'MONTE ALEGRE DOS CAMPOS',
255: 'MONTE BELO DO SUL',
256: 'MONTENEGRO',
257: 'MORMAÇO',
258: 'MORRINHOS DO SUL',
259: 'MORRO REDONDO',
260: 'MORRO REUTER',
261: 'MOSTARDAS',
262: 'MUÇUM',
263: 'MUITOS CAPÕES',
264: 'MULITERNO',
265: 'NÃO-ME-TOQUE',
266: 'NICOLAU VERGUEIRO',
267: 'NONOAI',
268: 'NOVA ALVORADA',
269: 'NOVA ARAÇÁ',
270: 'NOVA BASSANO',
271: 'NOVA BOA VISTA',
272: 'NOVA BRÉSCIA',
273: 'NOVA CANDELÁRIA',
274: 'NOVA ESPERANÇA DO SUL',
275: 'NOVA HARTZ',
276: 'NOVA PÁDUA',
277: 'NOVA PALMA',
278: 'NOVA PETRÓPOLIS',
279: 'NOVA PRATA',
280: 'NOVA RAMADA',
281: 'NOVA ROMA DO SUL',
282: 'NOVA SANTA RITA',
283: 'NOVO CABRAIS',
284: 'NOVO HAMBURGO',
285: 'NOVO MACHADO',
286: 'NOVO TIRADENTES',
287: 'NOVO XINGU',
288: 'NOVO BARREIRO',
289: 'OSÓRIO',
290: 'PAIM FILHO',
291: 'PALMARES DO SUL',
292: 'PALMEIRA DAS MISSÕES',
293: 'PALMITINHO',
294: 'PANAMBI',
295: 'PANTANO GRANDE',
296: 'PARAÍ',
297: 'PARAÍSO DO SUL',
298: 'PARECI NOVO',
299: 'PAROBÉ',
300: 'PASSA SETE',
301: 'PASSO DO SOBRADO',
302: 'PASSO FUNDO',
303: 'PAULO BENTO',
304: 'PAVERAMA',
305: 'PEDRAS ALTAS',
306: 'PEDRO OSÓRIO',
307: 'PEJUÇARA',
308: 'PELOTAS',
309: 'PICADA CAFÉ',
310: 'PINHAL',
311: 'PINHAL DA SERRA',
312: 'PINHAL GRANDE',
313: 'PINHEIRINHO DO VALE',
314: 'PINHEIRO MACHADO',
315: 'PINTO BANDEIRA',
316: 'PIRAPÓ',
317: 'PIRATINI',
318: 'PLANALTO',
319: 'POÇO DAS ANTAS',
320: 'PONTÃO',
321: 'PONTE PRETA',
322: 'PORTÃO',
323: 'PORTO ALEGRE',
324: 'PORTO LUCENA',
325: 'PORTO MAUÁ',
326: 'PORTO VERA CRUZ',
327: 'PORTO XAVIER',
328: 'POUSO NOVO',
329: 'PRESIDENTE LUCENA',
330: 'PROGRESSO',
331: 'PROTÁSIO ALVES',
332: 'PUTINGA',
333: 'QUARAÍ',
334: 'QUATRO IRMÃOS',
335: 'QUEVEDOS',
336: 'QUINZE DE NOVEMBRO',
337: 'REDENTORA',
338: 'RELVADO',
339: 'RESTINGA SECA',
340: 'RIO DOS ÍNDIOS',
341: 'RIO GRANDE',
342: 'RIO PARDO',
343: 'RIOZINHO',
344: 'ROCA SALES',
345: 'RODEIO BONITO',
346: 'ROLADOR',
347: 'ROLANTE',
348: 'RONDA ALTA',
349: 'RONDINHA',
350: 'ROQUE GONZALES',
351: 'ROSÁRIO DO SUL',
352: 'SAGRADA FAMÍLIA',
353: 'SALDANHA MARINHO',
354: 'SALTO DO JACUÍ',
355: 'SALVADOR DAS MISSÕES',
356: 'SALVADOR DO SUL',
357: 'SANANDUVA',
358: 'SANTA BÁRBARA DO SUL',
359: 'SANTA CECÍLIA DO SUL',
360: 'SANTA CLARA DO SUL',
361: 'SANTA CRUZ DO SUL',
362: 'SANTA MARIA',
363: 'SANTA MARIA DO HERVAL',
364: 'SANTA MARGARIDA DO SUL',
365: 'SANTANA DA BOA VISTA',
366: 'SANTANA DO LIVRAMENTO',
367: 'SANTA ROSA',
368: 'SANTA TEREZA',
369: 'SANTA VITÓRIA DO PALMAR',
370: 'SANTIAGO',
371: 'SANTO ÂNGELO',
372: 'SANTO ANTÔNIO DO PALMA',
373: 'SANTO ANTÔNIO DA PATRULHA',
374: 'SANTO ANTÔNIO DAS MISSÕES',
375: 'SANTO ANTÔNIO DO PLANALTO',
376: 'SANTO AUGUSTO',
377: 'SANTO CRISTO',
378: 'SANTO EXPEDITO DO SUL',
379: 'SÃO BORJA',
380: 'SÃO DOMINGOS DO SUL',
381: 'SÃO FRANCISCO DE ASSIS',
382: 'SÃO FRANCISCO DE PAULA',
383: 'SÃO GABRIEL',
384: 'SÃO JERÔNIMO',
385: 'SÃO JOÃO DA URTIGA',
386: 'SÃO JOÃO DO POLÊSINE',
387: 'SÃO JORGE',
388: 'SÃO JOSÉ DAS MISSÕES',
389: 'SÃO JOSÉ DO HERVAL',
390: 'SÃO JOSÉ DO HORTÊNCIO',
391: 'SÃO JOSÉ DO INHACORÁ',
392: 'SÃO JOSÉ DO NORTE',
393: 'SÃO JOSÉ DO OURO',
394: 'SÃO JOSÉ DO SUL',
395: 'SÃO JOSÉ DOS AUSENTES',
396: 'SÃO LEOPOLDO',
397: 'SÃO LOURENÇO DO SUL',
398: 'SÃO LUIZ GONZAGA',
399: 'SÃO MARCOS',
400: 'SÃO MARTINHO',
401: 'SÃO MARTINHO DA SERRA',
402: 'SÃO MIGUEL DAS MISSÕES',
403: 'SÃO NICOLAU',
404: 'SÃO PAULO DAS MISSÕES',
405: 'SÃO PEDRO DA SERRA',
406: 'SÃO PEDRO DAS MISSÕES',
407: 'SÃO PEDRO DO BUTIÁ',
408: 'SÃO PEDRO DO SUL',
409: 'SÃO SEBASTIÃO DO CAÍ',
410: 'SÃO SEPÉ',
411: 'SÃO VALENTIM',
412: 'SÃO VALENTIM DO SUL',
413: 'SÃO VALÉRIO DO SUL',
414: 'SÃO VENDELINO',
415: 'SÃO VICENTE DO SUL',
416: 'SAPIRANGA',
417: 'SAPUCAIA DO SUL',
418: 'SARANDI',
419: 'SEBERI',
420: 'SEDE NOVA',
421: 'SEGREDO',
422: 'SELBACH',
423: 'SENADOR SALGADO FILHO',
424: 'SENTINELA DO SUL',
425: 'SERAFINA CORRÊA',
426: 'SÉRIO',
427: 'SERTÃO',
428: 'SERTÃO SANTANA',
429: 'SETE DE SETEMBRO',
430: 'SEVERIANO DE ALMEIDA',
431: 'SILVEIRA MARTINS',
432: 'SINIMBU',
433: 'SOBRADINHO',
434: 'SOLEDADE',
435: 'TABAÍ',
436: 'TAPEJARA',
437: 'TAPERA',
438: 'TAPES',
439: 'TAQUARA',
440: 'TAQUARI',
441: 'TAQUARUÇU DO SUL',
442: 'TAVARES',
443: 'TENENTE PORTELA',
444: 'TERRA DE AREIA',
445: 'TEUTÔNIA',
446: 'TIO HUGO',
447: 'TIRADENTES DO SUL',
448: 'TOROPI',
449: 'TORRES',
450: 'TRAMANDAÍ',
451: 'TRAVESSEIRO',
452: 'TRÊS ARROIOS',
453: 'TRÊS CACHOEIRAS',
454: 'TRÊS COROAS',
455: 'TRÊS DE MAIO',
456: 'TRÊS FORQUILHAS',
457: 'TRÊS PALMEIRAS',
458: 'TRÊS PASSOS',
459: 'TRINDADE DO SUL',
460: 'TRIUNFO',
461: 'TUCUNDUVA',
462: 'TUNAS',
463: 'TUPANCI DO SUL',
464: 'TUPANCIRETÃ',
465: 'TUPANDI',
466: 'TUPARENDI',
467: 'TURUÇU',
468: 'UBIRETAMA',
469: 'UNIÃO DA SERRA',
470: 'UNISTALDA',
471: 'URUGUAIANA',
472: 'VACARIA',
473: 'VALE VERDE',
474: 'VALE DO SOL',
475: 'VALE REAL',
476: 'VANINI',
477: 'VENÂNCIO AIRES',
478: 'VERA CRUZ',
479: 'VERANÓPOLIS',
480: 'VESPASIANO CORREA',
481: 'VIADUTOS',
482: 'VIAMÃO',
483: 'VICENTE DUTRA',
484: 'VICTOR GRAEFF',
485: 'VILA FLORES',
486: 'VILA LÂNGARO',
487: 'VILA MARIA',
488: 'VILA NOVA DO SUL',
489: 'VISTA ALEGRE',
490: 'VISTA ALEGRE DO PRATA',
491: 'VISTA GAÚCHA',
492: 'VITÓRIA DAS MISSÕES',
493: 'WESTFALIA',
494: 'XANGRI-LÁ',
495: 'Bebê',
496: 'Criança',
497: 'Jovem',
498: 'Adulto',
499: 'Idoso_1',
500: 'Idoso_2',
501: 'RT-PCR',
502: 'TESTE RÁPIDO',
503: 'Outros Testes',
504: 'Clínico-Imagem',
505: 'Clínico',
506: 'Clínico Epidemiológico',
507: 'Março',
508: 'Abril',
509: 'Maio',
510: 'Junho',
511: 'Julho',
512: 'Agosto',
513: 'Setembro',
514: 'Outubro',
515: 'RECUPERADO',
516: 'OBITO',
517: 'OBITO OUTRAS CAUSAS',
518: 'BRANCA',
519: 'NAO INFORMADO',
520: 'INDIGENA',
521: 'AMARELA',
522: 'PARDA',
523: 'PRETA',
524: 'SexF',
525: 'SexM',
526: 'Hospitalizado',
527: 'Hosp_SRAG',
528: 'Prof_Saude',
529: 'Febre',
530: 'Tosse',
531: 'Garganta',
532: 'Dispneia',
533: 'Outros_Sint',
534: 'Gestante',
535: 'Presidiario',
536: 'Asma',
537: 'DRespiratoria',
538: 'DNeurologica',
539: 'Diabetes',
540: 'Imunodef',
541: 'DRenal',
542: 'DHepatica',
543: 'DCardiaca',
544: 'Obesidade',
545: 'Outras_Comorbidades',
546: 'DCromossomica',
547: 'DHematologica',
548: 'Sindrome_down'}

# %% [markdown]
# O dicionário $region\_covid$ não possui os municípios, no lugar é posto as regiões. Além disso, a faixa-etaria dos pacientes foram um pouco mais divididas. O conjunto possui 79 atributos com 5729 pacientes.

# %%
region_covid = {
 0: 'BAGE - R22',
 1: 'PASSO FUNDO - R17 R18 R19',
 2: 'SANTA MARIA - R01 R02',
 3: 'IJUI - R13',
 4: 'SANTA ROSA - R14',
 5: 'URUGUAIANA - R03',
 6: 'PALMEIRA DAS MISSOES - R15 R20',
 7: 'CAXIAS DO SUL - R23 R24 R25 R26',
 8: 'PORTO ALEGRE - R10',
 9: 'PELOTAS - R21',
 10: 'LAJEADO - R29 R30',
 11: 'GUAIBA - R09',
 12: 'NOVO HAMBURGO - R07',
 13: 'ERECHIM - R16',
 14: 'CAPAO DA CANOA - R04 R05',
 15: 'CACHOEIRA DO SUL - R27',
 16: 'CANOAS - R08',
 17: 'CRUZ ALTA - R12',
 18: 'SANTO ANGELO - R11',
 19: 'TAQUARA - R06',
 20: 'SANTA CRUZ DO SUL - R28',
 21: 'Bebê',
 22: 'Criança',
 23: 'Jovem',
 24: 'Adulto_1',
 25: 'Adulto_2',
 26: 'Adulto_3',
 27: 'Idoso_1',
 28: 'Idoso_2',
 29: 'Idoso_3',
 30: 'RT-PCR',
 31: 'TESTE RÁPIDO',
 32: 'Outros Testes',
 33: 'Clínico-Imagem',
 34: 'Clínico',
 35: 'Clínico Epidemiológico',
 36: 'Março',
 37: 'Abril',
 38: 'Maio',
 39: 'Junho',
 40: 'Julho',
 41: 'Agosto',
 42: 'Setembro',
 43: 'Outubro',
 44: 'BRANCA',
 45: 'NAO INFORMADO',
 46: 'INDIGENA',
 47: 'AMARELA',
 48: 'PARDA',
 49: 'PRETA',
 50: 'SexF',
 51: 'SexM',
 52: 'Hospitalizado',
 53: 'Hosp_SRAG',
 54: 'Prof_Saude',
 55: 'Febre',
 56: 'Tosse',
 57: 'Garganta',
 58: 'Dispneia',
 59: 'Outros_Sint',
 60: 'Gestante',
 61: 'Presidiario',
 62: 'Asma',
 63: 'DRespiratoria',
 64: 'DNeurologica',
 65: 'Diabetes',
 66: 'Imunodef',
 67: 'DRenal',
 68: 'DHepatica',
 69: 'DCardiaca',
 70: 'Obesidade',
 71: 'Outras_Comorbidades',
 72: 'DCromossomica',
 73: 'DHematologica',
 74: 'Sindrome_down'
}

# %% [markdown]
# O dicionário $region\_obito\_mes$ tem o acréscimo sobre o mês de óbito do paciente.

# %%
region_obito_mes = {
 0: 'BAGE - R22',
 1: 'PASSO FUNDO - R17 R18 R19',
 2: 'SANTA MARIA - R01 R02',
 3: 'IJUI - R13',
 4: 'SANTA ROSA - R14',
 5: 'URUGUAIANA - R03',
 6: 'PALMEIRA DAS MISSOES - R15 R20',
 7: 'CAXIAS DO SUL - R23 R24 R25 R26',
 8: 'PORTO ALEGRE - R10',
 9: 'PELOTAS - R21',
 10: 'LAJEADO - R29 R30',
 11: 'GUAIBA - R09',
 12: 'NOVO HAMBURGO - R07',
 13: 'ERECHIM - R16',
 14: 'CAPAO DA CANOA - R04 R05',
 15: 'CACHOEIRA DO SUL - R27',
 16: 'CANOAS - R08',
 17: 'CRUZ ALTA - R12',
 18: 'SANTO ANGELO - R11',
 19: 'TAQUARA - R06',
 20: 'SANTA CRUZ DO SUL - R28',
 21: 'Bebê',
 22: 'Criança',
 23: 'Jovem',
 24: 'Adulto_1',
 25: 'Adulto_2',
 26: 'Adulto_3',
 27: 'Idoso_1',
 28: 'Idoso_2',
 29: 'Idoso_3',
 30: 'RT-PCR',
 31: 'TESTE RÁPIDO',
 32: 'Outros Testes',
 33: 'Clínico-Imagem',
 34: 'Clínico',
 35: 'Clínico Epidemiológico',
 36: 'Março',
 37: 'Abril',
 38: 'Maio',
 39: 'Junho',
 40: 'Julho',
 41: 'Agosto',
 42: 'Setembro',
 43: 'Outubro',
 44: 'Obito_Março',
 45: 'Obito_Abril',
 46: 'Obito_Maio',
 47: 'Obito_Junho',
 48: 'Obito_Julho',
 49: 'Obito_Agosto',
 50: 'Obito_Setembro',
 51: 'Obito_Outubro',
 52: 'BRANCA',
 53: 'NAO INFORMADO',
 54: 'INDIGENA',
 55: 'AMARELA',
 56: 'PARDA',
 57: 'PRETA',
 58: 'SexF',
 59: 'SexM',
 60: 'Hospitalizado',
 61: 'Hosp_SRAG',
 62: 'Prof_Saude',
 63: 'Febre',
 64: 'Tosse',
 65: 'Garganta',
 66: 'Dispneia',
 67: 'Outros_Sint',
 68: 'Gestante',
 69: 'Presidiario',
 70: 'Asma',
 71: 'DRespiratoria',
 72: 'DNeurologica',
 73: 'Diabetes',
 74: 'Imunodef',
 75: 'DRenal',
 76: 'DHepatica',
 77: 'DCardiaca',
 78: 'Obesidade',
 79: 'Outras_Comorbidades',
 80: 'DCromossomica',
 81: 'DHematologica',
 82: 'Sindrome_down'}

# %% [markdown]
# Dicionário para dataset de óbitos. Especificação considerando região e municipios

# %%
municipio_regiao_covid = {
 0: 'ACEGUÁ',
 1: 'ÁGUA SANTA',
 2: 'AGUDO',
 3: 'AJURICABA',
 4: 'ALECRIM',
 5: 'ALEGRETE',
 6: 'ALEGRIA',
 7: 'ALMIRANTE TAMANDARÉ DO SUL',
 8: 'ALPESTRE',
 9: 'ALTO ALEGRE',
 10: 'ALTO FELIZ',
 11: 'ALVORADA',
 12: 'AMARAL FERRADOR',
 13: 'AMETISTA DO SUL',
 14: 'ANDRÉ DA ROCHA',
 15: 'ANTA GORDA',
 16: 'ANTÔNIO PRADO',
 17: 'ARAMBARÉ',
 18: 'ARARICÁ',
 19: 'ARATIBA',
 20: 'ARROIO DO MEIO',
 21: 'ARROIO DO SAL',
 22: 'ARROIO DO PADRE',
 23: 'ARROIO DOS RATOS',
 24: 'ARROIO DO TIGRE',
 25: 'ARROIO GRANDE',
 26: 'ARVOREZINHA',
 27: 'AUGUSTO PESTANA',
 28: 'ÁUREA',
 29: 'BAGÉ',
 30: 'BALNEÁRIO PINHAL',
 31: 'BARÃO',
 32: 'BARÃO DE COTEGIPE',
 33: 'BARÃO DO TRIUNFO',
 34: 'BARRACÃO',
 35: 'BARRA DO GUARITA',
 36: 'BARRA DO QUARAÍ',
 37: 'BARRA DO RIBEIRO',
 38: 'BARRA DO RIO AZUL',
 39: 'BARRA FUNDA',
 40: 'BARROS CASSAL',
 41: 'BENJAMIN CONSTANT DO SUL',
 42: 'BENTO GONÇALVES',
 43: 'BOA VISTA DAS MISSÕES',
 44: 'BOA VISTA DO BURICÁ',
 45: 'BOA VISTA DO CADEADO',
 46: 'BOA VISTA DO INCRA',
 47: 'BOA VISTA DO SUL',
 48: 'BOM JESUS',
 49: 'BOM PRINCÍPIO',
 50: 'BOM PROGRESSO',
 51: 'BOM RETIRO DO SUL',
 52: 'BOQUEIRÃO DO LEÃO',
 53: 'BOSSOROCA',
 54: 'BOZANO',
 55: 'BRAGA',
 56: 'BROCHIER',
 57: 'BUTIÁ',
 58: 'CAÇAPAVA DO SUL',
 59: 'CACEQUI',
 60: 'CACHOEIRA DO SUL',
 61: 'CACHOEIRINHA',
 62: 'CACIQUE DOBLE',
 63: 'CAIBATÉ',
 64: 'CAIÇARA',
 65: 'CAMAQUÃ',
 66: 'CAMARGO',
 67: 'CAMBARÁ DO SUL',
 68: 'CAMPESTRE DA SERRA',
 69: 'CAMPINA DAS MISSÕES',
 70: 'CAMPINAS DO SUL',
 71: 'CAMPO BOM',
 72: 'CAMPO NOVO',
 73: 'CAMPOS BORGES',
 74: 'CANDELÁRIA',
 75: 'CÂNDIDO GODÓI',
 76: 'CANDIOTA',
 77: 'CANELA',
 78: 'CANGUÇU',
 79: 'CANOAS',
 80: 'CANUDOS DO VALE',
 81: 'CAPÃO BONITO DO SUL',
 82: 'CAPÃO DA CANOA',
 83: 'CAPÃO DO CIPÓ',
 84: 'CAPÃO DO LEÃO',
 85: 'CAPIVARI DO SUL',
 86: 'CAPELA DE SANTANA',
 87: 'CAPITÃO',
 88: 'CARAZINHO',
 89: 'CARAÁ',
 90: 'CARLOS BARBOSA',
 91: 'CARLOS GOMES',
 92: 'CASCA',
 93: 'CASEIROS',
 94: 'CATUÍPE',
 95: 'CAXIAS DO SUL',
 96: 'CENTENÁRIO',
 97: 'CERRITO',
 98: 'CERRO GRANDE',
 99: 'CERRO GRANDE DO SUL',
 100: 'CERRO LARGO',
 101: 'CHAPADA',
 102: 'CHARQUEADAS',
 103: 'CHARRUA',
 104: 'CHIAPETTA',
 105: 'CHUÍ',
 106: 'CHUVISCA',
 107: 'CIDREIRA',
 108: 'CIRÍACO',
 109: 'COLINAS',
 110: 'COLORADO',
 111: 'CONDOR',
 112: 'CONSTANTINA',
 113: 'COQUEIRO BAIXO',
 114: 'COQUEIROS DO SUL',
 115: 'CORONEL BARROS',
 116: 'CORONEL BICACO',
 117: 'CORONEL PILAR',
 118: 'COTIPORÃ',
 119: 'COXILHA',
 120: 'CRISSIUMAL',
 121: 'CRISTAL',
 122: 'CRISTAL DO SUL',
 123: 'CRUZ ALTA',
 124: 'CRUZALTENSE',
 125: 'CRUZEIRO DO SUL',
 126: 'DAVID CANABARRO',
 127: 'DERRUBADAS',
 128: 'DEZESSEIS DE NOVEMBRO',
 129: 'DILERMANDO DE AGUIAR',
 130: 'DOIS IRMÃOS',
 131: 'DOIS IRMÃOS DAS MISSÕES',
 132: 'DOIS LAJEADOS',
 133: 'DOM FELICIANO',
 134: 'DOM PEDRO DE ALCÂNTARA',
 135: 'DOM PEDRITO',
 136: 'DONA FRANCISCA',
 137: 'DOUTOR MAURÍCIO CARDOSO',
 138: 'DOUTOR RICARDO',
 139: 'ELDORADO DO SUL',
 140: 'ENCANTADO',
 141: 'ENCRUZILHADA DO SUL',
 142: 'ENGENHO VELHO',
 143: 'ENTRE-IJUÍS',
 144: 'ENTRE RIOS DO SUL',
 145: 'EREBANGO',
 146: 'ERECHIM',
 147: 'ERNESTINA',
 148: 'HERVAL',
 149: 'ERVAL GRANDE',
 150: 'ERVAL SECO',
 151: 'ESMERALDA',
 152: 'ESPERANÇA DO SUL',
 153: 'ESPUMOSO',
 154: 'ESTAÇÃO',
 155: 'ESTÂNCIA VELHA',
 156: 'ESTEIO',
 157: 'ESTRELA',
 158: 'ESTRELA VELHA',
 159: 'EUGÊNIO DE CASTRO',
 160: 'FAGUNDES VARELA',
 161: 'FARROUPILHA',
 162: 'FAXINAL DO SOTURNO',
 163: 'FAXINALZINHO',
 164: 'FAZENDA VILANOVA',
 165: 'FELIZ',
 166: 'FLORES DA CUNHA',
 167: 'FLORIANO PEIXOTO',
 168: 'FONTOURA XAVIER',
 169: 'FORMIGUEIRO',
 170: 'FORQUETINHA',
 171: 'FORTALEZA DOS VALOS',
 172: 'FREDERICO WESTPHALEN',
 173: 'GARIBALDI',
 174: 'GAURAMA',
 175: 'GENERAL CÂMARA',
 176: 'GENTIL',
 177: 'GETÚLIO VARGAS',
 178: 'GIRUÁ',
 179: 'GLORINHA',
 180: 'GRAMADO',
 181: 'GRAMADO DOS LOUREIROS',
 182: 'GRAMADO XAVIER',
 183: 'GRAVATAÍ',
 184: 'GUABIJU',
 185: 'GUAÍBA',
 186: 'GUAPORÉ',
 187: 'GUARANI DAS MISSÕES',
 188: 'HARMONIA',
 189: 'HERVEIRAS',
 190: 'HORIZONTINA',
 191: 'HULHA NEGRA',
 192: 'HUMAITÁ',
 193: 'IBARAMA',
 194: 'IBIAÇÁ',
 195: 'IBIRAIARAS',
 196: 'IBIRAPUITÃ',
 197: 'IBIRUBÁ',
 198: 'IGREJINHA',
 199: 'IJUÍ',
 200: 'ILÓPOLIS',
 201: 'IMBÉ',
 202: 'IMIGRANTE',
 203: 'INDEPENDÊNCIA',
 204: 'INHACORÁ',
 205: 'IPÊ',
 206: 'IPIRANGA DO SUL',
 207: 'IRAÍ',
 208: 'ITAARA',
 209: 'ITACURUBI',
 210: 'ITAPUCA',
 211: 'ITAQUI',
 212: 'ITATI',
 213: 'ITATIBA DO SUL',
 214: 'IVORÁ',
 215: 'IVOTI',
 216: 'JABOTICABA',
 217: 'JACUIZINHO',
 218: 'JACUTINGA',
 219: 'JAGUARÃO',
 220: 'JAGUARI',
 221: 'JAQUIRANA',
 222: 'JARI',
 223: 'JÓIA',
 224: 'JÚLIO DE CASTILHOS',
 225: 'LAGOA BONITA DO SUL',
 226: 'LAGOÃO',
 227: 'LAGOA DOS TRÊS CANTOS',
 228: 'LAGOA VERMELHA',
 229: 'LAJEADO',
 230: 'LAJEADO DO BUGRE',
 231: 'LAVRAS DO SUL',
 232: 'LIBERATO SALZANO',
 233: 'LINDOLFO COLLOR',
 234: 'LINHA NOVA',
 235: 'MACHADINHO',
 236: 'MAÇAMBARÁ',
 237: 'MAMPITUBA',
 238: 'MANOEL VIANA',
 239: 'MAQUINÉ',
 240: 'MARATÁ',
 241: 'MARAU',
 242: 'MARCELINO RAMOS',
 243: 'MARIANA PIMENTEL',
 244: 'MARIANO MORO',
 245: 'MARQUES DE SOUZA',
 246: 'MATA',
 247: 'MATO CASTELHANO',
 248: 'MATO LEITÃO',
 249: 'MATO QUEIMADO',
 250: 'MAXIMILIANO DE ALMEIDA',
 251: 'MINAS DO LEÃO',
 252: 'MIRAGUAÍ',
 253: 'MONTAURI',
 254: 'MONTE ALEGRE DOS CAMPOS',
 255: 'MONTE BELO DO SUL',
 256: 'MONTENEGRO',
 257: 'MORMAÇO',
 258: 'MORRINHOS DO SUL',
 259: 'MORRO REDONDO',
 260: 'MORRO REUTER',
 261: 'MOSTARDAS',
 262: 'MUÇUM',
 263: 'MUITOS CAPÕES',
 264: 'MULITERNO',
 265: 'NÃO-ME-TOQUE',
 266: 'NICOLAU VERGUEIRO',
 267: 'NONOAI',
 268: 'NOVA ALVORADA',
 269: 'NOVA ARAÇÁ',
 270: 'NOVA BASSANO',
 271: 'NOVA BOA VISTA',
 272: 'NOVA BRÉSCIA',
 273: 'NOVA CANDELÁRIA',
 274: 'NOVA ESPERANÇA DO SUL',
 275: 'NOVA HARTZ',
 276: 'NOVA PÁDUA',
 277: 'NOVA PALMA',
 278: 'NOVA PETRÓPOLIS',
 279: 'NOVA PRATA',
 280: 'NOVA RAMADA',
 281: 'NOVA ROMA DO SUL',
 282: 'NOVA SANTA RITA',
 283: 'NOVO CABRAIS',
 284: 'NOVO HAMBURGO',
 285: 'NOVO MACHADO',
 286: 'NOVO TIRADENTES',
 287: 'NOVO XINGU',
 288: 'NOVO BARREIRO',
 289: 'OSÓRIO',
 290: 'PAIM FILHO',
 291: 'PALMARES DO SUL',
 292: 'PALMEIRA DAS MISSÕES',
 293: 'PALMITINHO',
 294: 'PANAMBI',
 295: 'PANTANO GRANDE',
 296: 'PARAÍ',
 297: 'PARAÍSO DO SUL',
 298: 'PARECI NOVO',
 299: 'PAROBÉ',
 300: 'PASSA SETE',
 301: 'PASSO DO SOBRADO',
 302: 'PASSO FUNDO',
 303: 'PAULO BENTO',
 304: 'PAVERAMA',
 305: 'PEDRAS ALTAS',
 306: 'PEDRO OSÓRIO',
 307: 'PEJUÇARA',
 308: 'PELOTAS',
 309: 'PICADA CAFÉ',
 310: 'PINHAL',
 311: 'PINHAL DA SERRA',
 312: 'PINHAL GRANDE',
 313: 'PINHEIRINHO DO VALE',
 314: 'PINHEIRO MACHADO',
 315: 'PINTO BANDEIRA',
 316: 'PIRAPÓ',
 317: 'PIRATINI',
 318: 'PLANALTO',
 319: 'POÇO DAS ANTAS',
 320: 'PONTÃO',
 321: 'PONTE PRETA',
 322: 'PORTÃO',
 323: 'PORTO ALEGRE',
 324: 'PORTO LUCENA',
 325: 'PORTO MAUÁ',
 326: 'PORTO VERA CRUZ',
 327: 'PORTO XAVIER',
 328: 'POUSO NOVO',
 329: 'PRESIDENTE LUCENA',
 330: 'PROGRESSO',
 331: 'PROTÁSIO ALVES',
 332: 'PUTINGA',
 333: 'QUARAÍ',
 334: 'QUATRO IRMÃOS',
 335: 'QUEVEDOS',
 336: 'QUINZE DE NOVEMBRO',
 337: 'REDENTORA',
 338: 'RELVADO',
 339: 'RESTINGA SECA',
 340: 'RIO DOS ÍNDIOS',
 341: 'RIO GRANDE',
 342: 'RIO PARDO',
 343: 'RIOZINHO',
 344: 'ROCA SALES',
 345: 'RODEIO BONITO',
 346: 'ROLADOR',
 347: 'ROLANTE',
 348: 'RONDA ALTA',
 349: 'RONDINHA',
 350: 'ROQUE GONZALES',
 351: 'ROSÁRIO DO SUL',
 352: 'SAGRADA FAMÍLIA',
 353: 'SALDANHA MARINHO',
 354: 'SALTO DO JACUÍ',
 355: 'SALVADOR DAS MISSÕES',
 356: 'SALVADOR DO SUL',
 357: 'SANANDUVA',
 358: 'SANTA BÁRBARA DO SUL',
 359: 'SANTA CECÍLIA DO SUL',
 360: 'SANTA CLARA DO SUL',
 361: 'SANTA CRUZ DO SUL',
 362: 'SANTA MARIA',
 363: 'SANTA MARIA DO HERVAL',
 364: 'SANTA MARGARIDA DO SUL',
 365: 'SANTANA DA BOA VISTA',
 366: 'SANTANA DO LIVRAMENTO',
 367: 'SANTA ROSA',
 368: 'SANTA TEREZA',
 369: 'SANTA VITÓRIA DO PALMAR',
 370: 'SANTIAGO',
 371: 'SANTO ÂNGELO',
 372: 'SANTO ANTÔNIO DO PALMA',
 373: 'SANTO ANTÔNIO DA PATRULHA',
 374: 'SANTO ANTÔNIO DAS MISSÕES',
 375: 'SANTO ANTÔNIO DO PLANALTO',
 376: 'SANTO AUGUSTO',
 377: 'SANTO CRISTO',
 378: 'SANTO EXPEDITO DO SUL',
 379: 'SÃO BORJA',
 380: 'SÃO DOMINGOS DO SUL',
 381: 'SÃO FRANCISCO DE ASSIS',
 382: 'SÃO FRANCISCO DE PAULA',
 383: 'SÃO GABRIEL',
 384: 'SÃO JERÔNIMO',
 385: 'SÃO JOÃO DA URTIGA',
 386: 'SÃO JOÃO DO POLÊSINE',
 387: 'SÃO JORGE',
 388: 'SÃO JOSÉ DAS MISSÕES',
 389: 'SÃO JOSÉ DO HERVAL',
 390: 'SÃO JOSÉ DO HORTÊNCIO',
 391: 'SÃO JOSÉ DO INHACORÁ',
 392: 'SÃO JOSÉ DO NORTE',
 393: 'SÃO JOSÉ DO OURO',
 394: 'SÃO JOSÉ DO SUL',
 395: 'SÃO JOSÉ DOS AUSENTES',
 396: 'SÃO LEOPOLDO',
 397: 'SÃO LOURENÇO DO SUL',
 398: 'SÃO LUIZ GONZAGA',
 399: 'SÃO MARCOS',
 400: 'SÃO MARTINHO',
 401: 'SÃO MARTINHO DA SERRA',
 402: 'SÃO MIGUEL DAS MISSÕES',
 403: 'SÃO NICOLAU',
 404: 'SÃO PAULO DAS MISSÕES',
 405: 'SÃO PEDRO DA SERRA',
 406: 'SÃO PEDRO DAS MISSÕES',
 407: 'SÃO PEDRO DO BUTIÁ',
 408: 'SÃO PEDRO DO SUL',
 409: 'SÃO SEBASTIÃO DO CAÍ',
 410: 'SÃO SEPÉ',
 411: 'SÃO VALENTIM',
 412: 'SÃO VALENTIM DO SUL',
 413: 'SÃO VALÉRIO DO SUL',
 414: 'SÃO VENDELINO',
 415: 'SÃO VICENTE DO SUL',
 416: 'SAPIRANGA',
 417: 'SAPUCAIA DO SUL',
 418: 'SARANDI',
 419: 'SEBERI',
 420: 'SEDE NOVA',
 421: 'SEGREDO',
 422: 'SELBACH',
 423: 'SENADOR SALGADO FILHO',
 424: 'SENTINELA DO SUL',
 425: 'SERAFINA CORRÊA',
 426: 'SÉRIO',
 427: 'SERTÃO',
 428: 'SERTÃO SANTANA',
 429: 'SETE DE SETEMBRO',
 430: 'SEVERIANO DE ALMEIDA',
 431: 'SILVEIRA MARTINS',
 432: 'SINIMBU',
 433: 'SOBRADINHO',
 434: 'SOLEDADE',
 435: 'TABAÍ',
 436: 'TAPEJARA',
 437: 'TAPERA',
 438: 'TAPES',
 439: 'TAQUARA',
 440: 'TAQUARI',
 441: 'TAQUARUÇU DO SUL',
 442: 'TAVARES',
 443: 'TENENTE PORTELA',
 444: 'TERRA DE AREIA',
 445: 'TEUTÔNIA',
 446: 'TIO HUGO',
 447: 'TIRADENTES DO SUL',
 448: 'TOROPI',
 449: 'TORRES',
 450: 'TRAMANDAÍ',
 451: 'TRAVESSEIRO',
 452: 'TRÊS ARROIOS',
 453: 'TRÊS CACHOEIRAS',
 454: 'TRÊS COROAS',
 455: 'TRÊS DE MAIO',
 456: 'TRÊS FORQUILHAS',
 457: 'TRÊS PALMEIRAS',
 458: 'TRÊS PASSOS',
 459: 'TRINDADE DO SUL',
 460: 'TRIUNFO',
 461: 'TUCUNDUVA',
 462: 'TUNAS',
 463: 'TUPANCI DO SUL',
 464: 'TUPANCIRETÃ',
 465: 'TUPANDI',
 466: 'TUPARENDI',
 467: 'TURUÇU',
 468: 'UBIRETAMA',
 469: 'UNIÃO DA SERRA',
 470: 'UNISTALDA',
 471: 'URUGUAIANA',
 472: 'VACARIA',
 473: 'VALE VERDE',
 474: 'VALE DO SOL',
 475: 'VALE REAL',
 476: 'VANINI',
 477: 'VENÂNCIO AIRES',
 478: 'VERA CRUZ',
 479: 'VERANÓPOLIS',
 480: 'VESPASIANO CORREA',
 481: 'VIADUTOS',
 482: 'VIAMÃO',
 483: 'VICENTE DUTRA',
 484: 'VICTOR GRAEFF',
 485: 'VILA FLORES',
 486: 'VILA LÂNGARO',
 487: 'VILA MARIA',
 488: 'VILA NOVA DO SUL',
 489: 'VISTA ALEGRE',
 490: 'VISTA ALEGRE DO PRATA',
 491: 'VISTA GAÚCHA',
 492: 'VITÓRIA DAS MISSÕES',
 493: 'WESTFALIA',
 494: 'XANGRI-LÁ',
 495: 'BAGE - R22',
 496: 'PASSO FUNDO - R17 R18 R19',
 497: 'SANTA MARIA - R01 R02',
 498: 'IJUI - R13',
 499: 'SANTA ROSA - R14',
 500: 'URUGUAIANA - R03',
 501: 'PALMEIRA DAS MISSOES - R15 R20',
 502: 'CAXIAS DO SUL - R23 R24 R25 R26',
 503: 'PORTO ALEGRE - R10',
 504: 'PELOTAS - R21',
 505: 'LAJEADO - R29 R30',
 506: 'GUAIBA - R09',
 507: 'NOVO HAMBURGO - R07',
 508: 'ERECHIM - R16',
 509: 'CAPAO DA CANOA - R04 R05',
 510: 'CACHOEIRA DO SUL - R27',
 511: 'CANOAS - R08',
 512: 'CRUZ ALTA - R12',
 513: 'SANTO ANGELO - R11',
 514: 'TAQUARA - R06',
 515: 'SANTA CRUZ DO SUL - R28',
 516: 'Bebê',
 517: 'Criança',
 518: 'Jovem',
 519: 'Adulto_1',
 520: 'Adulto_2',
 521: 'Adulto_3',
 522: 'Idoso_1',
 523: 'Idoso_2',
 524: 'Idoso_3',
 525: 'RT-PCR',
 526: 'TESTE RÁPIDO',
 527: 'Outros Testes',
 528: 'Clínico-Imagem',
 529: 'Clínico',
 530: 'Clínico Epidemiológico',
 531: 'Março',
 532: 'Abril',
 533: 'Maio',
 534: 'Junho',
 535: 'Julho',
 536: 'Agosto',
 537: 'Setembro',
 538: 'Outubro',
 539: 'Obito_Março',
 540: 'Obito_Abril',
 541: 'Obito_Maio',
 542: 'Obito_Junho',
 543: 'Obito_Julho',
 544: 'Obito_Agosto',
 545: 'Obito_Setembro',
 546: 'Obito_Outubro',
 547: 'BRANCA',
 548: 'NAO INFORMADO',
 549: 'INDIGENA',
 550: 'AMARELA',
 551: 'PARDA',
 552: 'PRETA',
 553: 'SexF',
 554: 'SexM',
 555: 'Hospitalizado',
 556: 'Hosp_SRAG',
 557: 'Prof_Saude',
 558: 'Febre',
 559: 'Tosse',
 560: 'Garganta',
 561: 'Dispneia',
 562: 'Outros_Sint',
 563: 'Gestante',
 564: 'Presidiario',
 565: 'Asma',
 566: 'DRespiratoria',
 567: 'DNeurologica',
 568: 'Diabetes',
 569: 'Imunodef',
 570: 'DRenal',
 571: 'DHepatica',
 572: 'DCardiaca',
 573: 'Obesidade',
 574: 'Outras_Comorbidades',
 575: 'DCromossomica',
 576: 'DHematologica',
 577: 'Sindrome_down'
}
